# %% [markdown]
# # test1

# %%
# langchain_google_genai 패키지 설치
# !pip install langchain-google-genai

# 관련 패키지 설치
# !pip install google-generativeai langchain langchain_community faiss-cpu

# %%
import os
import json
import logging
import time
from datetime import datetime
from pathlib import Path
import concurrent.futures
import torch
from tqdm import tqdm
import random
from google import genai

# 로깅 설정
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

class MedicalVectorStore:
    """
    의료 데이터를 위한 벡터 스토어 구축 클래스
    """
    def __init__(self, data_path="./medical_data", vector_store_path="./vector_stores", use_gpu=True, api_key=None):
        """
        초기화 함수
        
        Args:
            data_path: 의료 데이터가 저장된 경로
            vector_store_path: 벡터 스토어를 저장할 경로
            use_gpu: GPU 사용 여부
            api_key: Google API 키
        """
        self.data_path = Path(data_path)
        self.vector_store_path = Path(vector_store_path)
        self.api_key = api_key

        # 기본 디렉토리 생성
        self.data_path.mkdir(parents=True, exist_ok=True)
        self.vector_store_path.mkdir(parents=True, exist_ok=True)

        # GPU 사용 여부 확인
        self.device = "cuda" if use_gpu and torch.cuda.is_available() else "cpu"
        logger.info(f"Using device: {self.device}")

        # API 키 확인
        if not self.api_key:
            raise ValueError("Google API 키가 필요합니다.")

        # Google API 클라이언트 직접 생성
        self.client = genai.Client(api_key=self.api_key)
        
        # API 속도 제한 관리를 위한 변수
        self.request_timestamps = []
        self.max_requests_per_minute = 4
        self.daily_request_count = 0
        self.daily_reset_time = time.time() + 86400

        # 커스텀 임베딩 클래스 생성 (LangChain 호환)
        class GeminiEmbeddings:
            def __init__(self, client):
                self.client = client
            
            def embed_documents(self, texts):
                # 이 메서드는 실제로 사용되지 않음 (embed_query만 사용)
                raise NotImplementedError("이 메서드는 사용하지 않습니다.")
            
            def embed_query(self, text):
                # 쿼리 임베딩만 필요 (검색 시)
                result = self.client.models.embed_content(
                    model="models/gemini-embedding-exp-03-07",  # 문서 임베딩과 동일한 모델 사용
                    contents=[text],
                    config={"task_type": "retrieval_query"}
                )
                return result.embeddings[0].values
        
        # 커스텀 임베딩 인스턴스 생성
        self.embeddings_for_search = GeminiEmbeddings(self.client)

        from langchain.text_splitter import RecursiveCharacterTextSplitter

        # 문서 분할기 설정
        self.text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=500,
            chunk_overlap=100,
            separators=["\n\n", "\n", ". ", " ", ""],
            length_function=len
        )

    def _wait_for_rate_limit(self):
        """API 요청 속도 제한을 관리하는 메서드"""
        current_time = time.time()
        
        # 하루 제한 확인 및 초기화
        if current_time > self.daily_reset_time:
            logger.info("일일 요청 카운터 초기화")
            self.daily_request_count = 0
            self.daily_reset_time = current_time + 86400
        
        # 하루 제한에 도달했는지 확인
        if self.daily_request_count >= 300:  # 하루 90회 제한
            remaining_time = self.daily_reset_time - current_time
            logger.warning(f"일일 API 요청 한도(90회)에 도달했습니다. {remaining_time/3600:.1f}시간 후 재설정됩니다.")
            time.sleep(min(remaining_time, 3600))  # 최대 1시간 대기
            return self._wait_for_rate_limit()
        
        # 분당 요청 제한 관리
        self.request_timestamps = [t for t in self.request_timestamps if current_time - t < 60]
        
        if len(self.request_timestamps) >= self.max_requests_per_minute:
            oldest_request = min(self.request_timestamps)
            wait_time = (oldest_request + 60) - current_time + 2  # 2초 버퍼 추가
            logger.info(f"분당 요청 한도에 도달했습니다. {wait_time:.1f}초 대기 중...")
            time.sleep(max(wait_time, 0))
            return self._wait_for_rate_limit()

    def _embed_documents(self, texts, max_retries=5, retry_delay=10):
        """
        직접 Google API를 호출하여 임베딩 생성
        """
        retries = 0
        while retries < max_retries:
            try:
                # 속도 제한 관리
                self._wait_for_rate_limit()
                
                # 현재 시간 기록
                current_time = time.time()
                self.request_timestamps.append(current_time)
                self.daily_request_count += 1
                
                logger.info(f"임베딩 API 호출 (배치 크기: {len(texts)}, 분당 요청: {len(self.request_timestamps)}/{self.max_requests_per_minute}, 일일 요청: {self.daily_request_count}/90)")
                
                # 직접 API 호출
                result = self.client.models.embed_content(
                    model="models/gemini-embedding-exp-03-07",
                    contents=texts,
                    config={"task_type": "retrieval_document"}
                )
                
                # 결과 추출
                embeddings = [embedding.values for embedding in result.embeddings]
                
                return embeddings
            except Exception as e:
                logger.warning(f"임베딩 생성 중 오류 발생 (시도 {retries+1}/{max_retries}): {e}")
                retries += 1
                if retries >= max_retries:
                    logger.error(f"최대 재시도 횟수 초과. 실패: {e}")
                    raise
                wait_time = retry_delay * (2 ** (retries - 1)) + random.uniform(1, 5)
                logger.info(f"{wait_time:.1f}초 후 재시도합니다...")
                time.sleep(wait_time)

    def load_medical_data(self, file_pattern="*_patients.json"):
        """
        의료 데이터 로드 - 병렬 처리
        """
        import glob

        data_files = list(self.data_path.glob(file_pattern))

        if not data_files:
            logger.warning(f"No files matching {file_pattern} found in {self.data_path}")
            return []

        # 병렬 처리로 여러 파일 동시 로드
        documents = []

        with concurrent.futures.ThreadPoolExecutor(max_workers=min(len(data_files), os.cpu_count())) as executor:
            future_to_file = {
                executor.submit(self._load_single_file, file_path): file_path
                for file_path in data_files
            }

            for future in tqdm(concurrent.futures.as_completed(future_to_file),
                               total=len(future_to_file),
                               desc="Loading files"):
                file_docs = future.result()
                if file_docs:
                    documents.extend(file_docs)

        logger.info(f"Loaded {len(documents)} total documents from medical data")
        return documents

    def _load_single_file(self, file_path):
        """
        단일 파일 로드 (병렬 처리용) - 테스트를 위해 환자 수 제한 가능
        """
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                patients = json.load(f)

            department = file_path.stem.replace("_patients", "")
            
            # 테스트를 위해 환자 수 제한 (전체 데이터 처리가 부담스러우면 주석 해제)
            # patients = patients[:5]  # 각 파일에서 5명만 처리
            
            logger.info(f"Loading {len(patients)} patients from {department} department")

            # 각 환자 정보를 문서로 변환
            docs = []
            for patient in patients:
                docs.extend(self._convert_patient_to_documents(patient, department))

            return docs

        except Exception as e:
            logger.error(f"Error loading {file_path}: {e}")
            return []


    def _convert_patient_to_documents(self, patient, department):
            """
            환자 정보를 여러 개의 문서로 변환 (세분화된 정보)
            """
            from langchain.schema import Document

            documents = []

            # 환자 기본 정보 문서
            basic_info = f"""
            환자 ID: {patient['id']}
            이름: {patient['name']}
            성별: {patient['gender']}
            나이: {patient['age']}
            생년월일: {patient['birthdate']}
            혈액형: {patient.get('blood_type', '정보 없음')}
            키: {patient.get('height', '정보 없음')} cm
            체중: {patient.get('weight', '정보 없음')} kg
            BMI: {patient.get('bmi', '정보 없음')}
            주소: {patient.get('address', '정보 없음')}
            전화번호: {patient.get('phone', '정보 없음')}
            보험: {patient.get('insurance', '정보 없음')}
            진료과: {department}
            """

            if patient.get('allergies'):
                basic_info += f"\n알레르기: {', '.join(patient['allergies'])}"

            if patient.get('smoking'):
                basic_info += f"\n흡연: {patient['smoking']['status']}"
                if patient['smoking'].get('details'):
                    basic_info += f" ({patient['smoking']['details']})"

            if patient.get('alcohol'):
                basic_info += f"\n음주: {patient['alcohol']['status']}"
                if patient['alcohol'].get('details'):
                    basic_info += f" ({patient['alcohol']['details']})"

            documents.append(Document(
                page_content=basic_info.strip(),
                metadata={
                    "patient_id": patient['id'],
                    "name": patient['name'],
                    "gender": patient['gender'],
                    "age": patient['age'],
                    "department": department,
                    "document_type": "basic_info"
                }
            ))

            # 진단 정보 문서
            if patient.get('diagnoses'):
                for i, diagnosis in enumerate(patient['diagnoses']):
                    diagnosis_doc = f"""
                    환자 ID: {patient['id']}
                    이름: {patient['name']}
                    성별: {patient['gender']}
                    나이: {patient['age']}

                    [진단 정보 {i+1}]
                    진단명: {diagnosis['name']}
                    ICD10 코드: {diagnosis.get('icd10', '정보 없음')}
                    진단일: {diagnosis.get('date', '정보 없음')}
                    진단 의사: {diagnosis.get('doctor', '정보 없음')} (ID: {diagnosis.get('doctor_id', '정보 없음')})
                    확신도: {diagnosis.get('confidence', '정보 없음')}
                    상태: {diagnosis.get('status', '정보 없음')}
                    중증도: {diagnosis.get('severity', '정보 없음')}
                    메모: {diagnosis.get('memo', '정보 없음')}
                    증상: {', '.join(diagnosis.get('symptoms', ['정보 없음']))}
                    """

                    documents.append(Document(
                        page_content=diagnosis_doc.strip(),
                        metadata={
                            "patient_id": patient['id'],
                            "name": patient['name'],
                            "gender": patient['gender'],
                            "age": patient['age'],
                            "department": department,
                            "document_type": "diagnosis",
                            "diagnosis_name": diagnosis['name'],
                            "diagnosis_date": diagnosis.get('date', ''),
                            "diagnosis_status": diagnosis.get('status', '')
                        }
                    ))

            # 약물 정보 문서
            if patient.get('medications'):
                for i, medication in enumerate(patient['medications']):
                    medication_doc = f"""
                    환자 ID: {patient['id']}
                    이름: {patient['name']}
                    성별: {patient['gender']}
                    나이: {patient['age']}

                    [약물 정보 {i+1}]
                    약물명: {medication['medication']}
                    약물 분류: {medication.get('class', '정보 없음')}
                    처방일: {medication.get('prescription_date', '정보 없음')}
                    처방 기간: {medication.get('duration_days', '정보 없음')}일
                    용량: {medication.get('dosage', '정보 없음')}
                    빈도: {medication.get('frequency', '정보 없음')}
                    재처방 횟수: {medication.get('refill', '정보 없음')}
                    처방 의사: {medication.get('doctor', '정보 없음')} (ID: {medication.get('doctor_id', '정보 없음')})
                    관련 진단: {medication.get('related_diagnosis', '정보 없음')}
                    특별 지시사항: {medication.get('special_instructions', '정보 없음')}
                    """

                    documents.append(Document(
                        page_content=medication_doc.strip(),
                        metadata={
                            "patient_id": patient['id'],
                            "name": patient['name'],
                            "gender": patient['gender'],
                            "age": patient['age'],
                            "department": department,
                            "document_type": "medication",
                            "medication_name": medication['medication'],
                            "medication_class": medication.get('class', ''),
                            "related_diagnosis": medication.get('related_diagnosis', '')
                        }
                    ))

            # 검사 결과 문서
            if patient.get('lab_results'):
                for i, lab in enumerate(patient['lab_results']):
                    lab_doc = f"""
                    환자 ID: {patient['id']}
                    이름: {patient['name']}
                    성별: {patient['gender']}
                    나이: {patient['age']}

                    [검사 결과 {i+1}]
                    검사일: {lab.get('date', '정보 없음')}
                    검사 유형: {lab.get('test_type', '정보 없음')}
                    검사 요청 의사: {lab.get('ordering_doctor', '정보 없음')} (ID: {lab.get('ordering_doctor_id', '정보 없음')})
                    검사 ID: {lab.get('lab_id', '정보 없음')}
                    검체 채취 시간: {lab.get('collection_time', '정보 없음')}
                    보고 시간: {lab.get('report_time', '정보 없음')}

                    결과 항목:
                    """

                    for test_name, test_result in lab.get('results', {}).items():
                        lab_doc += f"""
                        - {test_name}: {test_result.get('value', '정보 없음')} {test_result.get('unit', '')}
                        (정상 범위: {test_result.get('normal_range', '정보 없음')})
                        {test_result.get('flag', '')}
                        """

                    if lab.get('interpretation'):
                        lab_doc += f"\n해석: {lab['interpretation']}"

                    documents.append(Document(
                        page_content=lab_doc.strip(),
                        metadata={
                            "patient_id": patient['id'],
                            "name": patient['name'],
                            "gender": patient['gender'],
                            "age": patient['age'],
                            "department": department,
                            "document_type": "lab_result",
                            "lab_date": lab.get('date', ''),
                            "test_type": lab.get('test_type', '')
                        }
                    ))

            # 영상 검사 문서
            if patient.get('imaging_studies'):
                for i, study in enumerate(patient['imaging_studies']):
                    imaging_doc = f"""
                    환자 ID: {patient['id']}
                    이름: {patient['name']}
                    성별: {patient['gender']}
                    나이: {patient['age']}

                    [영상 검사 {i+1}]
                    검사일: {study.get('date', '정보 없음')}
                    검사 유형: {study.get('study_type', '정보 없음')}
                    검사 요청 의사: {study.get('ordering_doctor', '정보 없음')} (ID: {study.get('ordering_doctor_id', '정보 없음')})
                    영상의학과 의사: {study.get('radiologist', '정보 없음')}
                    검사 ID: {study.get('study_id', '정보 없음')}

                    소견: {study.get('findings', '정보 없음')}
                    판독: {study.get('impression', '정보 없음')}
                    추천: {study.get('recommendation', '정보 없음')}
                    """

                    documents.append(Document(
                        page_content=imaging_doc.strip(),
                        metadata={
                            "patient_id": patient['id'],
                            "name": patient['name'],
                            "gender": patient['gender'],
                            "age": patient['age'],
                            "department": department,
                            "document_type": "imaging_study",
                            "study_date": study.get('date', ''),
                            "study_type": study.get('study_type', '')
                        }
                    ))

            # 시술 및 수술 문서
            if patient.get('procedures'):
                for i, procedure in enumerate(patient['procedures']):
                    procedure_doc = f"""
                    환자 ID: {patient['id']}
                    이름: {patient['name']}
                    성별: {patient['gender']}
                    나이: {patient['age']}

                    [시술/수술 {i+1}]
                    시술일: {procedure.get('date', '정보 없음')}
                    시술명: {procedure.get('name', '정보 없음')}
                    설명: {procedure.get('description', '정보 없음')}
                    시술 의사: {procedure.get('performing_doctor', '정보 없음')} (ID: {procedure.get('performing_doctor_id', '정보 없음')})
                    시술 ID: {procedure.get('procedure_id', '정보 없음')}
                    위치: {procedure.get('location', '정보 없음')}
                    마취: {procedure.get('anesthesia', '정보 없음')}
                    소요 시간: {procedure.get('duration_minutes', '정보 없음')}분
                    결과: {procedure.get('outcome', '정보 없음')}
                    """

                    if procedure.get('complications'):
                        procedure_doc += f"\n합병증: {', '.join(procedure['complications'])}"

                    procedure_doc += f"\n추적 관찰: {procedure.get('follow_up', '정보 없음')}"

                    documents.append(Document(
                        page_content=procedure_doc.strip(),
                        metadata={
                            "patient_id": patient['id'],
                            "name": patient['name'],
                            "gender": patient['gender'],
                            "age": patient['age'],
                            "department": department,
                            "document_type": "procedure",
                            "procedure_date": procedure.get('date', ''),
                            "procedure_name": procedure.get('name', ''),
                            "outcome": procedure.get('outcome', '')
                        }
                    ))

            # 진료 기록 문서
            if patient.get('visits'):
                for i, visit in enumerate(patient['visits']):
                    visit_doc = f"""
                    환자 ID: {patient['id']}
                    이름: {patient['name']}
                    성별: {patient['gender']}
                    나이: {patient['age']}

                    [진료 기록 {i+1}]
                    방문 ID: {visit.get('visit_id', '정보 없음')}
                    방문일: {visit.get('date', '정보 없음')}
                    방문 시간: {visit.get('time', '정보 없음')}
                    방문 유형: {visit.get('type', '정보 없음')}
                    진료과: {visit.get('department', '정보 없음')}
                    담당 의사: {visit.get('doctor', '정보 없음')} (ID: {visit.get('doctor_id', '정보 없음')})
                    주 호소: {visit.get('chief_complaint', '정보 없음')}

                    활력 징후:
                    수축기 혈압: {visit.get('vital_signs', {}).get('systolic_bp', '정보 없음')} mmHg
                    이완기 혈압: {visit.get('vital_signs', {}).get('diastolic_bp', '정보 없음')} mmHg
                    맥박: {visit.get('vital_signs', {}).get('pulse', '정보 없음')} bpm
                    체온: {visit.get('vital_signs', {}).get('temperature', '정보 없음')} °C
                    호흡수: {visit.get('vital_signs', {}).get('respiratory_rate', '정보 없음')} /분
                    산소포화도: {visit.get('vital_signs', {}).get('oxygen_saturation', '정보 없음')} %
                    """

                    if 'blood_glucose' in visit.get('vital_signs', {}):
                        visit_doc += f"혈당: {visit['vital_signs']['blood_glucose']} mg/dL\n"

                    visit_doc += f"""
                    임상 노트:
                    주관적(S): {visit.get('clinical_note', {}).get('subjective', '정보 없음')}
                    객관적(O): {visit.get('clinical_note', {}).get('objective', '정보 없음')}
                    평가(A): {visit.get('clinical_note', {}).get('assessment', '정보 없음')}
                    계획(P): {visit.get('clinical_note', {}).get('plan', '정보 없음')}

                    진료 시간: {visit.get('duration_minutes', '정보 없음')}분
                    """

                    if visit.get('next_appointment'):
                        visit_doc += f"다음 예약: {visit['next_appointment']}"

                    documents.append(Document(
                        page_content=visit_doc.strip(),
                        metadata={
                            "patient_id": patient['id'],
                            "name": patient['name'],
                            "gender": patient['gender'],
                            "age": patient['age'],
                            "department": department,
                            "document_type": "visit",
                            "visit_date": visit.get('date', ''),
                            "visit_type": visit.get('type', ''),
                            "chief_complaint": visit.get('chief_complaint', '')
                        }
                    ))

            # 통합 문서 (전체 환자 기록을 하나의 문서로)
            integrated_doc = f"""
            [환자 통합 기록]
            환자 ID: {patient['id']}
            이름: {patient['name']}
            성별: {patient['gender']}
            나이: {patient['age']}
            생년월일: {patient['birthdate']}
            진료과: {department}

            [진단 요약]
            """

            if patient.get('diagnoses'):
                for diagnosis in patient['diagnoses']:
                    integrated_doc += f"""
                    - {diagnosis['name']} ({diagnosis.get('date', '날짜 없음')})
                    상태: {diagnosis.get('status', '정보 없음')}, 중증도: {diagnosis.get('severity', '정보 없음')}
                    """
            else:
                integrated_doc += "진단 정보 없음\n"

            integrated_doc += "\n[약물 요약]\n"
            if patient.get('medications'):
                for med in patient['medications']:
                    integrated_doc += f"""
                    - {med['medication']} {med.get('dosage', '')} {med.get('frequency', '')}
                    처방일: {med.get('prescription_date', '정보 없음')}, 관련 진단: {med.get('related_diagnosis', '정보 없음')}
                    """
            else:
                integrated_doc += "약물 정보 없음\n"

            integrated_doc += "\n[최근 검사 결과 요약]\n"
            if patient.get('lab_results'):
                # 가장 최근 검사 결과만 포함
                recent_lab = max(patient['lab_results'], key=lambda x: x.get('date', ''))
                integrated_doc += f"검사일: {recent_lab.get('date', '정보 없음')}, 검사 유형: {recent_lab.get('test_type', '정보 없음')}\n"

                for test_name, test_result in recent_lab.get('results', {}).items():
                    flag = test_result.get('flag', '')
                    if flag:
                        integrated_doc += f"- {test_name}: {test_result.get('value', '')} {test_result.get('unit', '')} ({flag})\n"
            else:
                integrated_doc += "검사 결과 정보 없음\n"

            integrated_doc += "\n[최근 방문 요약]\n"
            if patient.get('visits'):
                # 가장 최근 방문만 포함
                recent_visit = max(patient['visits'], key=lambda x: x.get('date', ''))
                integrated_doc += f"""
                방문일: {recent_visit.get('date', '정보 없음')}
                주 호소: {recent_visit.get('chief_complaint', '정보 없음')}
                평가: {recent_visit.get('clinical_note', {}).get('assessment', '정보 없음')}
                계획: {recent_visit.get('clinical_note', {}).get('plan', '정보 없음')}
                """
            else:
                integrated_doc += "방문 기록 없음\n"

            documents.append(Document(
                page_content=integrated_doc.strip(),
                metadata={
                    "patient_id": patient['id'],
                    "name": patient['name'],
                    "gender": patient['gender'],
                    "age": patient['age'],
                    "department": department,
                    "document_type": "integrated_record"
                }
            ))

            return documents

    def create_vector_store(self, documents, store_name="medical_vector_store", batch_size=1):
        """
        벡터 스토어 생성 - API 직접 호출 방식
        """
        if not documents:
            logger.warning("벡터 스토어를 생성할 문서가 없습니다.")
            return None

        logger.info(f"{len(documents)}개 문서로 벡터 스토어 생성 중...")

        # 문서를 청크로 분할
        chunks = self.text_splitter.split_documents(documents)
        logger.info(f"총 {len(chunks)}개의 청크 생성")

        from langchain_community.vectorstores import FAISS
        
        # 진행 상황 추적 파일
        store_path = self.vector_store_path / store_name
        store_path.mkdir(parents=True, exist_ok=True)
        progress_file = self.vector_store_path / f"{store_name}_progress.txt"
        start_index = 0
        
        # 진행 상황 파일 확인
        if progress_file.exists():
            try:
                with open(progress_file, "r") as f:
                    start_index = int(f.read().strip())
                logger.info(f"이전 진행 상황 발견, 인덱스 {start_index}부터 재개합니다.")
            except Exception as e:
                logger.warning(f"진행 상황 파일 읽기 실패, 처음부터 시작합니다: {e}")
        
        # 기존 벡터 스토어 확인
        vectorstore = None
        if start_index > 0 and store_path.exists():
            try:
                logger.info(f"기존 벡터 스토어 로드 중: {store_path}")
                vectorstore = FAISS.load_local(
                    store_path,
                    self.embeddings_for_search,
                    allow_dangerous_deserialization=True
                )
                logger.info("기존 벡터 스토어 로드 완료")
            except Exception as e:
                logger.warning(f"기존 벡터 스토어 로드 실패, 새로 시작합니다: {e}")
                start_index = 0
        
        # 청크 처리
        try:
            # 처리할 청크들
            remaining_chunks = chunks[start_index:]
            
            # 배치 생성
            batches = []
            for i in range(0, len(remaining_chunks), batch_size):
                batches.append(remaining_chunks[i:i + batch_size])
            
            logger.info(f"{len(batches)}개의 배치로 처리 예정 (시작 인덱스: {start_index})")
            
            # 각 배치 처리
            for batch_idx, batch in enumerate(tqdm(batches, desc="배치 처리 중")):
                current_index = start_index + batch_idx * batch_size
                logger.info(f"배치 {batch_idx+1}/{len(batches)} 처리 중... (인덱스 {current_index})")
                
                # create_vector_store 메서드 내부의 배치 처리 코드 수정
                try:
                    # 텍스트 추출
                    texts = [doc.page_content for doc in batch]
                    metadatas = [doc.metadata for doc in batch]
                    
                    # 직접 임베딩 생성
                    embeddings = self._embed_documents(texts)
                    
                    # 임베딩 결과 디버그
                    logger.info(f"임베딩 결과: 길이={len(embeddings)}, 차원={len(embeddings[0])}")
                    
                    # 임베딩을 FAISS 포맷으로 변환
                    if batch_idx == 0 and vectorstore is None:
                        # 첫 번째 배치로 벡터 스토어 생성
                        try:
                            vectorstore = FAISS.from_embeddings(
                                text_embeddings=list(zip(texts, embeddings)),
                                embedding=self.embeddings_for_search,
                                metadatas=metadatas
                            )
                            logger.info("첫 번째 배치로 벡터 스토어 생성 완료")
                        except Exception as e:
                            logger.error(f"벡터 스토어 생성 오류: {e}")
                            # 오류 세부 정보 출력
                            import traceback
                            logger.error(traceback.format_exc())
                            raise
                    else:
                        # 기존 벡터 스토어에 추가
                        try:
                            vectorstore.add_embeddings(
                                text_embeddings=list(zip(texts, embeddings)),
                                metadatas=metadatas
                            )
                            logger.info(f"배치 {batch_idx+1} 벡터 스토어에 추가 완료")
                        except Exception as e:
                            logger.error(f"벡터 스토어 추가 오류: {e}")
                            # 오류 세부 정보 출력
                            import traceback
                            logger.error(traceback.format_exc())
                            raise
                    
                    # 진행 상황 업데이트
                    with open(progress_file, "w") as f:
                        f.write(str(current_index + len(batch)))
                    
                    # 10개 배치마다 또는 마지막 배치 후 저장
                    if (batch_idx + 1) % 10 == 0 or batch_idx == len(batches) - 1:
                        try:
                            vectorstore.save_local(store_path)
                            logger.info(f"벡터 스토어 저장 완료: 인덱스 {current_index + len(batch)}")
                        except Exception as e:
                            logger.error(f"벡터 스토어 저장 오류: {e}")
                            import traceback
                            logger.error(traceback.format_exc())
                    
                    # 배치 간 잠시 대기
                    time.sleep(random.uniform(0.5, 1.0))
                    
                except Exception as e:
                    logger.error(f"배치 {batch_idx+1} 처리 중 오류 발생: {e}")
                    # 현재 진행 상태 저장
                    with open(progress_file, "w") as f:
                        f.write(str(current_index))
                    time.sleep(5)  # 오류 후 더 긴 대기
                    continue
            
            # 모든 배치 처리 완료 후 최종 저장
            if vectorstore:
                vectorstore.save_local(store_path)
                logger.info(f"모든 청크 처리 완료! 벡터 스토어가 {store_path}에 저장되었습니다.")
                
                # 진행 상황 파일 삭제
                if progress_file.exists():
                    progress_file.unlink()
                    logger.info("진행 상황 파일 삭제됨")
            
            return vectorstore
                
        except Exception as e:
            logger.error(f"벡터 스토어 생성 중 심각한 오류 발생: {e}")
            return None
    
    def load_vector_store(self, store_name="medical_vector_store"):
        """
        저장된 벡터 스토어 로드
        """
        from langchain_community.vectorstores import FAISS

        store_path = self.vector_store_path / store_name

        if not store_path.exists():
            logger.error(f"벡터 스토어 경로가 존재하지 않습니다: {store_path}")
            return None

        logger.info(f"{store_path}에서 벡터 스토어 로드 중...")

        try:
            vectorstore = FAISS.load_local(
                store_path,
                self.embeddings_for_search,
                allow_dangerous_deserialization=True
            )
            logger.info("벡터 스토어 로드 완료")
            return vectorstore
        except Exception as e:
            logger.error(f"벡터 스토어 로드 중 오류 발생: {e}")
            return None

    def search_similar_documents(self, query, vectorstore, k=5, filter_dict=None):
        """
        유사 문서 검색
        """
        if not vectorstore:
            logger.error("유효한 벡터 스토어가 없습니다.")
            return []
        
        logger.info(f"쿼리로 검색 중: {query}")
        
        try:
            if filter_dict:
                # 메타데이터 필터 적용한 검색
                docs = vectorstore.similarity_search(
                    query, 
                    k=k,
                    filter=filter_dict
                )
            else:
                # 기본 유사도 검색
                docs = vectorstore.similarity_search(query, k=k)
            
            return docs
        except Exception as e:
            logger.error(f"검색 중 오류 발생: {e}")
            return []

# 메인 함수
def main():
    # 경로 설정
    current_dir = os.getcwd()
    data_path = os.path.join(current_dir, "medical_data")
    vector_store_path = os.path.join(current_dir, "vector_stores")
    
    # API 키 설정
    api_key = input("Google API 키를 입력하세요: ")
    
    # GPU 사용 가능 여부 확인
    use_gpu = torch.cuda.is_available()
    if use_gpu:
        logger.info(f"GPU 사용 가능: {torch.cuda.get_device_name(0)}")
    else:
        logger.info("GPU를 사용할 수 없습니다. CPU로 실행합니다.")

    # 벡터 스토어 객체 초기화
    vs_builder = MedicalVectorStore(
        data_path=data_path,
        vector_store_path=vector_store_path,
        use_gpu=use_gpu,
        api_key=api_key
    )
    
    # 의료 데이터 로드
    logger.info("의료 데이터 로드 중...")
    documents = vs_builder.load_medical_data()
    
    # 벡터 스토어 생성
    logger.info("벡터 스토어 구축 중...")
    vectorstore = vs_builder.create_vector_store(documents, batch_size=1)

    if vectorstore:
        logger.info("벡터 스토어 구축 완료!")
        
        # 간단한 검색 테스트
        test_query = "고혈압 환자의 최근 혈압 측정 기록"
        logger.info(f"테스트 쿼리 실행 중: {test_query}")
        
        results = vs_builder.search_similar_documents(test_query, vectorstore, k=3)
        logger.info(f"검색 결과: {len(results)}개 문서 찾음")
        
        # 결과 예시 출력
        for i, doc in enumerate(results):
            logger.info(f"결과 {i+1} - {doc.metadata.get('document_type')}: {doc.page_content[:150]}...")

if __name__ == "__main__":
    main()
# Out:
# 2025-05-21 01:21:04,856 - INFO - GPU를 사용할 수 없습니다. CPU로 실행합니다.
# 2025-05-21 01:21:04,857 - INFO - Using device: cpu
# 2025-05-21 01:21:05,272 - INFO - 의료 데이터 로드 중...
# 2025-05-21 01:21:05,278 - INFO - Loading 25 patients from cardiology department
# 2025-05-21 01:21:05,285 - INFO - Loading 40 patients from emergency department
# 2025-05-21 01:21:05,289 - INFO - Loading 50 patients from internal_medicine department
# 2025-05-21 01:21:05,292 - INFO - Loading 20 patients from neurology department
# 2025-05-21 01:21:05,292 - INFO - Loading 30 patients from surgery department
# Loading files: 100%|██████████| 5/5 [00:00<00:00, 34.22it/s]
# 2025-05-21 01:21:05,448 - INFO - Loaded 2210 total documents from medical data
# 2025-05-21 01:21:05,449 - INFO - 벡터 스토어 구축 중...
# 2025-05-21 01:21:05,449 - INFO - 2210개 문서로 벡터 스토어 생성 중...
# 2025-05-21 01:21:05,645 - INFO - 총 5632개의 청크 생성
# 2025-05-21 01:21:05,666 - INFO - 이전 진행 상황 발견, 인덱스 407부터 재개합니다.
# 2025-05-21 01:21:05,666 - INFO - 기존 벡터 스토어 로드 중: c:\GitHubRepo\Medical-Artificial-Intelligence-Platform\VectorStore2\vector_stores\medical_vector_store
# 2025-05-21 01:21:05,672 - INFO - Loading faiss with AVX2 support.
# 2025-05-21 01:21:05,701 - INFO - Successfully loaded faiss with AVX2 support.
# 2025-05-21 01:21:05,711 - INFO - Failed to load GPU Faiss: name 'GpuIndexIVFFlat' is not defined. Will not load constructor refs for GPU indexes. This is only an error if you're trying to use GPU Faiss.
# 2025-05-21 01:21:05,731 - WARNING - `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.
# 2025-05-21 01:21:05,732 - INFO - 기존 벡터 스토어 로드 완료
# 2025-05-21 01:21:05,735 - INFO - 5225개의 배치로 처리 예정 (시작 인덱스: 407)
# 배치 처리 중:   0%|          | 0/5225 [00:00<?, ?it/s]2025-05-21 01:21:05,737 - INFO - 배치 1/5225 처리 중... (인덱스 407)
# 2025-05-21 01:21:05,737 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 1/4, 일일 요청: 1/90)
# 2025-05-21 01:21:06,621 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:21:06,668 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:21:06,669 - INFO - 배치 1 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 1/5225 [00:01<2:40:57,  1.85s/it]2025-05-21 01:21:07,585 - INFO - 배치 2/5225 처리 중... (인덱스 408)
# 2025-05-21 01:21:07,585 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 2/4, 일일 요청: 2/90)
# 2025-05-21 01:21:08,333 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:21:08,358 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:21:08,360 - INFO - 배치 2 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 2/5225 [00:03<2:32:08,  1.75s/it]2025-05-21 01:21:09,262 - INFO - 배치 3/5225 처리 중... (인덱스 409)
# 2025-05-21 01:21:09,263 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 3/90)
# 2025-05-21 01:21:09,980 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:21:09,998 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:21:09,999 - INFO - 배치 3 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 3/5225 [00:05<2:30:05,  1.72s/it]2025-05-21 01:21:10,960 - INFO - 배치 4/5225 처리 중... (인덱스 410)
# 2025-05-21 01:21:10,960 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 4/90)
# 2025-05-21 01:21:11,660 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:21:11,677 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:21:11,678 - INFO - 배치 4 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 4/5225 [00:06<2:26:20,  1.68s/it]2025-05-21 01:21:12,576 - INFO - 배치 5/5225 처리 중... (인덱스 411)
# 2025-05-21 01:21:12,577 - INFO - 분당 요청 한도에 도달했습니다. 55.2초 대기 중...
# 2025-05-21 01:22:07,738 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 5/90)
# 2025-05-21 01:22:09,253 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:22:09,301 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:22:09,303 - INFO - 배치 5 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 5/5225 [01:04<31:41:58, 21.86s/it]2025-05-21 01:22:10,219 - INFO - 배치 6/5225 처리 중... (인덱스 412)
# 2025-05-21 01:22:10,220 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 6/90)
# 2025-05-21 01:22:10,934 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:22:10,951 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:22:10,951 - INFO - 배치 6 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 6/5225 [01:06<21:40:13, 14.95s/it]2025-05-21 01:22:11,746 - INFO - 배치 7/5225 처리 중... (인덱스 413)
# 2025-05-21 01:22:11,747 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 7/90)
# 2025-05-21 01:22:12,473 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:22:12,491 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:22:12,492 - INFO - 배치 7 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 7/5225 [01:07<15:24:15, 10.63s/it]2025-05-21 01:22:13,479 - INFO - 배치 8/5225 처리 중... (인덱스 414)
# 2025-05-21 01:22:13,479 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 8/90)
# 2025-05-21 01:22:14,183 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:22:14,202 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:22:14,203 - INFO - 배치 8 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 8/5225 [01:09<11:06:09,  7.66s/it]2025-05-21 01:22:14,789 - INFO - 배치 9/5225 처리 중... (인덱스 415)
# 2025-05-21 01:22:14,790 - INFO - 분당 요청 한도에 도달했습니다. 54.9초 대기 중...
# 2025-05-21 01:23:09,739 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 9/90)
# 2025-05-21 01:23:10,643 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:23:10,688 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:23:10,690 - INFO - 배치 9 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 9/5225 [02:05<33:22:49, 23.04s/it]2025-05-21 01:23:11,639 - INFO - 배치 10/5225 처리 중... (인덱스 416)
# 2025-05-21 01:23:11,641 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 10/90)
# 2025-05-21 01:23:12,330 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:23:12,348 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:23:12,349 - INFO - 배치 10 벡터 스토어에 추가 완료
# 2025-05-21 01:23:12,357 - INFO - 벡터 스토어 저장 완료: 인덱스 417
# 배치 처리 중:   0%|          | 10/5225 [02:07<23:38:44, 16.32s/it]2025-05-21 01:23:12,925 - INFO - 배치 11/5225 처리 중... (인덱스 417)
# 2025-05-21 01:23:12,926 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 11/90)
# 2025-05-21 01:23:13,652 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:23:13,668 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:23:13,669 - INFO - 배치 11 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 11/5225 [02:08<17:03:37, 11.78s/it]2025-05-21 01:23:14,402 - INFO - 배치 12/5225 처리 중... (인덱스 418)
# 2025-05-21 01:23:14,404 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 12/90)
# 2025-05-21 01:23:15,104 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:23:15,120 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:23:15,121 - INFO - 배치 12 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 12/5225 [02:10<12:32:19,  8.66s/it]2025-05-21 01:23:15,925 - INFO - 배치 13/5225 처리 중... (인덱스 419)
# 2025-05-21 01:23:15,925 - INFO - 분당 요청 한도에 도달했습니다. 55.8초 대기 중...
# 2025-05-21 01:24:11,741 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 13/90)
# 2025-05-21 01:24:12,593 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:24:12,635 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:24:12,637 - INFO - 배치 13 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 13/5225 [03:07<34:01:24, 23.50s/it]2025-05-21 01:24:13,575 - INFO - 배치 14/5225 처리 중... (인덱스 420)
# 2025-05-21 01:24:13,576 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 14/90)
# 2025-05-21 01:24:14,309 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:24:14,330 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:24:14,332 - INFO - 배치 14 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 14/5225 [03:09<24:21:01, 16.82s/it]2025-05-21 01:24:14,967 - INFO - 배치 15/5225 처리 중... (인덱스 421)
# 2025-05-21 01:24:14,967 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 15/90)
# 2025-05-21 01:24:15,693 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:24:15,710 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:24:15,711 - INFO - 배치 15 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 15/5225 [03:10<17:44:06, 12.25s/it]2025-05-21 01:24:16,636 - INFO - 배치 16/5225 처리 중... (인덱스 422)
# 2025-05-21 01:24:16,637 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 16/90)
# 2025-05-21 01:24:17,338 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:24:17,353 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:24:17,353 - INFO - 배치 16 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 16/5225 [03:12<13:04:53,  9.04s/it]2025-05-21 01:24:18,213 - INFO - 배치 17/5225 처리 중... (인덱스 423)
# 2025-05-21 01:24:18,213 - INFO - 분당 요청 한도에 도달했습니다. 55.5초 대기 중...
# 2025-05-21 01:25:13,744 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 17/90)
# 2025-05-21 01:25:14,580 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:25:14,624 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:25:14,625 - INFO - 배치 17 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 17/5225 [04:09<34:06:47, 23.58s/it]2025-05-21 01:25:15,607 - INFO - 배치 18/5225 처리 중... (인덱스 424)
# 2025-05-21 01:25:15,608 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 18/90)
# 2025-05-21 01:25:16,307 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:25:16,324 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:25:16,325 - INFO - 배치 18 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 18/5225 [04:11<24:30:07, 16.94s/it]2025-05-21 01:25:17,090 - INFO - 배치 19/5225 처리 중... (인덱스 425)
# 2025-05-21 01:25:17,090 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 19/90)
# 2025-05-21 01:25:17,810 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:25:17,827 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:25:17,829 - INFO - 배치 19 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 19/5225 [04:12<17:49:50, 12.33s/it]2025-05-21 01:25:18,680 - INFO - 배치 20/5225 처리 중... (인덱스 426)
# 2025-05-21 01:25:18,681 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 20/90)
# 2025-05-21 01:25:19,380 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:25:19,398 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:25:19,400 - INFO - 배치 20 벡터 스토어에 추가 완료
# 2025-05-21 01:25:19,408 - INFO - 벡터 스토어 저장 완료: 인덱스 427
# 배치 처리 중:   0%|          | 20/5225 [04:14<13:07:13,  9.07s/it]2025-05-21 01:25:20,168 - INFO - 배치 21/5225 처리 중... (인덱스 427)
# 2025-05-21 01:25:20,168 - INFO - 분당 요청 한도에 도달했습니다. 55.6초 대기 중...
# 2025-05-21 01:26:15,745 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 21/90)
# 2025-05-21 01:26:17,242 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:26:17,283 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:26:17,284 - INFO - 배치 21 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 21/5225 [05:12<34:20:41, 23.76s/it]2025-05-21 01:26:18,162 - INFO - 배치 22/5225 처리 중... (인덱스 428)
# 2025-05-21 01:26:18,163 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 22/90)
# 2025-05-21 01:26:18,882 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:26:18,897 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:26:18,897 - INFO - 배치 22 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 22/5225 [05:13<24:42:28, 17.10s/it]2025-05-21 01:26:19,719 - INFO - 배치 23/5225 처리 중... (인덱스 429)
# 2025-05-21 01:26:19,720 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 23/90)
# 2025-05-21 01:26:20,426 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:26:20,441 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:26:20,443 - INFO - 배치 23 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 23/5225 [05:15<17:52:31, 12.37s/it]2025-05-21 01:26:21,068 - INFO - 배치 24/5225 처리 중... (인덱스 430)
# 2025-05-21 01:26:21,069 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 24/90)
# 2025-05-21 01:26:21,778 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:26:21,793 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:26:21,793 - INFO - 배치 24 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 24/5225 [05:16<13:12:36,  9.14s/it]2025-05-21 01:26:22,685 - INFO - 배치 25/5225 처리 중... (인덱스 431)
# 2025-05-21 01:26:22,686 - INFO - 분당 요청 한도에 도달했습니다. 55.1초 대기 중...
# 2025-05-21 01:27:17,747 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 25/90)
# 2025-05-21 01:27:18,573 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:27:18,614 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:27:18,615 - INFO - 배치 25 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 25/5225 [06:13<33:53:15, 23.46s/it]2025-05-21 01:27:19,546 - INFO - 배치 26/5225 처리 중... (인덱스 432)
# 2025-05-21 01:27:19,546 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 26/90)
# 2025-05-21 01:27:20,235 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:27:20,251 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:27:20,251 - INFO - 배치 26 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 26/5225 [06:15<24:23:00, 16.88s/it]2025-05-21 01:27:21,087 - INFO - 배치 27/5225 처리 중... (인덱스 433)
# 2025-05-21 01:27:21,087 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 27/90)
# 2025-05-21 01:27:21,783 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:27:21,799 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:27:21,800 - INFO - 배치 27 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 27/5225 [06:17<17:47:54, 12.33s/it]2025-05-21 01:27:22,780 - INFO - 배치 28/5225 처리 중... (인덱스 434)
# 2025-05-21 01:27:22,781 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 28/90)
# 2025-05-21 01:27:23,493 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:27:23,509 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:27:23,511 - INFO - 배치 28 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 28/5225 [06:18<12:59:49,  9.00s/it]2025-05-21 01:27:24,029 - INFO - 배치 29/5225 처리 중... (인덱스 435)
# 2025-05-21 01:27:24,029 - INFO - 분당 요청 한도에 도달했습니다. 55.7초 대기 중...
# 2025-05-21 01:28:19,748 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 29/90)
# 2025-05-21 01:28:20,612 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:28:20,652 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:28:20,652 - INFO - 배치 29 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 29/5225 [07:15<33:55:40, 23.51s/it]2025-05-21 01:28:21,375 - INFO - 배치 30/5225 처리 중... (인덱스 436)
# 2025-05-21 01:28:21,376 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 30/90)
# 2025-05-21 01:28:22,094 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:28:22,109 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:28:22,110 - INFO - 배치 30 벡터 스토어에 추가 완료
# 2025-05-21 01:28:22,118 - INFO - 벡터 스토어 저장 완료: 인덱스 437
# 배치 처리 중:   1%|          | 30/5225 [07:17<24:25:59, 16.93s/it]2025-05-21 01:28:22,966 - INFO - 배치 31/5225 처리 중... (인덱스 437)
# 2025-05-21 01:28:22,966 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 31/90)
# 2025-05-21 01:28:23,682 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:28:23,696 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:28:23,697 - INFO - 배치 31 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 31/5225 [07:18<17:43:36, 12.29s/it]2025-05-21 01:28:24,415 - INFO - 배치 32/5225 처리 중... (인덱스 438)
# 2025-05-21 01:28:24,415 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 32/90)
# 2025-05-21 01:28:26,998 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:28:27,013 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:28:27,013 - INFO - 배치 32 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 32/5225 [07:22<13:56:44,  9.67s/it]2025-05-21 01:28:27,972 - INFO - 배치 33/5225 처리 중... (인덱스 439)
# 2025-05-21 01:28:27,972 - INFO - 분당 요청 한도에 도달했습니다. 53.8초 대기 중...
# 2025-05-21 01:29:21,749 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 33/90)
# 2025-05-21 01:29:22,601 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:29:22,649 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:29:22,651 - INFO - 배치 33 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 33/5225 [08:17<33:50:10, 23.46s/it]2025-05-21 01:29:23,616 - INFO - 배치 34/5225 처리 중... (인덱스 440)
# 2025-05-21 01:29:23,617 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 34/90)
# 2025-05-21 01:29:24,328 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:29:24,346 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:29:24,347 - INFO - 배치 34 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 34/5225 [08:19<24:23:27, 16.92s/it]2025-05-21 01:29:25,258 - INFO - 배치 35/5225 처리 중... (인덱스 441)
# 2025-05-21 01:29:25,259 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 35/90)
# 2025-05-21 01:29:25,959 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:29:25,976 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:29:25,978 - INFO - 배치 35 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 35/5225 [08:20<17:37:34, 12.23s/it]2025-05-21 01:29:26,545 - INFO - 배치 36/5225 처리 중... (인덱스 442)
# 2025-05-21 01:29:26,545 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 36/90)
# 2025-05-21 01:29:29,209 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:29:29,227 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:29:29,228 - INFO - 배치 36 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 36/5225 [08:24<13:55:08,  9.66s/it]2025-05-21 01:29:30,204 - INFO - 배치 37/5225 처리 중... (인덱스 443)
# 2025-05-21 01:29:30,205 - INFO - 분당 요청 한도에 도달했습니다. 53.5초 대기 중...
# 2025-05-21 01:30:23,750 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 37/90)
# 2025-05-21 01:30:25,624 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:30:25,672 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:30:25,673 - INFO - 배치 37 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 37/5225 [09:20<34:05:04, 23.65s/it]2025-05-21 01:30:26,512 - INFO - 배치 38/5225 처리 중... (인덱스 444)
# 2025-05-21 01:30:26,513 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 38/90)
# 2025-05-21 01:30:27,207 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:30:27,228 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:30:27,229 - INFO - 배치 38 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 38/5225 [09:22<24:34:38, 17.06s/it]2025-05-21 01:30:28,183 - INFO - 배치 39/5225 처리 중... (인덱스 445)
# 2025-05-21 01:30:28,184 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 39/90)
# 2025-05-21 01:30:28,893 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:30:28,910 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:30:28,911 - INFO - 배치 39 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 39/5225 [09:23<17:49:24, 12.37s/it]2025-05-21 01:30:29,624 - INFO - 배치 40/5225 처리 중... (인덱스 446)
# 2025-05-21 01:30:29,625 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 40/90)
# 2025-05-21 01:30:30,359 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:30:30,378 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:30:30,379 - INFO - 배치 40 벡터 스토어에 추가 완료
# 2025-05-21 01:30:30,387 - INFO - 벡터 스토어 저장 완료: 인덱스 447
# 배치 처리 중:   1%|          | 40/5225 [09:25<13:12:28,  9.17s/it]2025-05-21 01:30:31,323 - INFO - 배치 41/5225 처리 중... (인덱스 447)
# 2025-05-21 01:30:31,323 - INFO - 분당 요청 한도에 도달했습니다. 54.4초 대기 중...
# 2025-05-21 01:31:25,751 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 41/90)
# 2025-05-21 01:31:26,590 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:31:26,632 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:31:26,633 - INFO - 배치 41 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 41/5225 [10:21<33:22:35, 23.18s/it]2025-05-21 01:31:27,186 - INFO - 배치 42/5225 처리 중... (인덱스 448)
# 2025-05-21 01:31:27,187 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 42/90)
# 2025-05-21 01:31:27,881 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:31:27,896 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:31:27,896 - INFO - 배치 42 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 42/5225 [10:22<24:01:22, 16.69s/it]2025-05-21 01:31:28,723 - INFO - 배치 43/5225 처리 중... (인덱스 449)
# 2025-05-21 01:31:28,723 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 43/90)
# 2025-05-21 01:31:30,098 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:31:30,113 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:31:30,114 - INFO - 배치 43 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 43/5225 [10:25<17:41:47, 12.29s/it]2025-05-21 01:31:30,769 - INFO - 배치 44/5225 처리 중... (인덱스 450)
# 2025-05-21 01:31:30,770 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 44/90)
# 2025-05-21 01:31:31,481 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:31:31,497 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:31:31,498 - INFO - 배치 44 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 44/5225 [10:26<13:02:40,  9.06s/it]2025-05-21 01:31:32,297 - INFO - 배치 45/5225 처리 중... (인덱스 451)
# 2025-05-21 01:31:32,298 - INFO - 분당 요청 한도에 도달했습니다. 55.5초 대기 중...
# 2025-05-21 01:32:27,752 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 45/90)
# 2025-05-21 01:32:28,546 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:32:28,579 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:32:28,580 - INFO - 배치 45 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 45/5225 [11:23<33:50:55, 23.52s/it]2025-05-21 01:32:29,561 - INFO - 배치 46/5225 처리 중... (인덱스 452)
# 2025-05-21 01:32:29,562 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 46/90)
# 2025-05-21 01:32:30,252 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:32:30,263 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:32:30,264 - INFO - 배치 46 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 46/5225 [11:25<24:24:36, 16.97s/it]2025-05-21 01:32:31,230 - INFO - 배치 47/5225 처리 중... (인덱스 453)
# 2025-05-21 01:32:31,231 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 47/90)
# 2025-05-21 01:32:31,935 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:32:31,949 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:32:31,950 - INFO - 배치 47 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 47/5225 [11:27<17:49:19, 12.39s/it]2025-05-21 01:32:32,942 - INFO - 배치 48/5225 처리 중... (인덱스 454)
# 2025-05-21 01:32:32,942 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 48/90)
# 2025-05-21 01:32:33,659 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:32:33,671 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:32:33,672 - INFO - 배치 48 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 48/5225 [11:28<13:02:11,  9.07s/it]2025-05-21 01:32:34,248 - INFO - 배치 49/5225 처리 중... (인덱스 455)
# 2025-05-21 01:32:34,248 - INFO - 분당 요청 한도에 도달했습니다. 55.5초 대기 중...
# 2025-05-21 01:33:29,753 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 49/90)
# 2025-05-21 01:33:31,164 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:33:31,206 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:33:31,208 - INFO - 배치 49 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 49/5225 [12:26<33:57:14, 23.62s/it]2025-05-21 01:33:31,814 - INFO - 배치 50/5225 처리 중... (인덱스 456)
# 2025-05-21 01:33:31,815 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 50/90)
# 2025-05-21 01:33:32,522 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:33:32,538 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:33:32,540 - INFO - 배치 50 벡터 스토어에 추가 완료
# 2025-05-21 01:33:32,548 - INFO - 벡터 스토어 저장 완료: 인덱스 457
# 배치 처리 중:   1%|          | 50/5225 [12:27<24:24:50, 16.98s/it]2025-05-21 01:33:33,323 - INFO - 배치 51/5225 처리 중... (인덱스 457)
# 2025-05-21 01:33:33,324 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 51/90)
# 2025-05-21 01:33:34,021 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:33:34,037 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:33:34,038 - INFO - 배치 51 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 51/5225 [12:28<17:38:26, 12.27s/it]2025-05-21 01:33:34,609 - INFO - 배치 52/5225 처리 중... (인덱스 458)
# 2025-05-21 01:33:34,609 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 52/90)
# 2025-05-21 01:33:35,329 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:33:35,345 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:33:35,346 - INFO - 배치 52 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 52/5225 [12:30<13:00:58,  9.06s/it]2025-05-21 01:33:36,164 - INFO - 배치 53/5225 처리 중... (인덱스 459)
# 2025-05-21 01:33:36,165 - INFO - 분당 요청 한도에 도달했습니다. 55.6초 대기 중...
# 2025-05-21 01:34:31,754 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 53/90)
# 2025-05-21 01:34:32,602 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:34:32,645 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:34:32,645 - INFO - 배치 53 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 53/5225 [13:27<33:49:01, 23.54s/it]2025-05-21 01:34:33,488 - INFO - 배치 54/5225 처리 중... (인덱스 460)
# 2025-05-21 01:34:33,489 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 54/90)
# 2025-05-21 01:34:34,184 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:34:34,201 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:34:34,202 - INFO - 배치 54 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 54/5225 [13:29<24:16:44, 16.90s/it]2025-05-21 01:34:34,909 - INFO - 배치 55/5225 처리 중... (인덱스 461)
# 2025-05-21 01:34:34,910 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 55/90)
# 2025-05-21 01:34:35,616 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:34:35,633 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:34:35,634 - INFO - 배치 55 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 55/5225 [13:30<17:39:55, 12.30s/it]2025-05-21 01:34:36,471 - INFO - 배치 56/5225 처리 중... (인덱스 462)
# 2025-05-21 01:34:36,471 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 56/90)
# 2025-05-21 01:34:37,175 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:34:37,193 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:34:37,194 - INFO - 배치 56 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 56/5225 [13:32<12:57:33,  9.03s/it]2025-05-21 01:34:37,854 - INFO - 배치 57/5225 처리 중... (인덱스 463)
# 2025-05-21 01:34:37,854 - INFO - 분당 요청 한도에 도달했습니다. 55.9초 대기 중...
# 2025-05-21 01:35:33,756 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 57/90)
# 2025-05-21 01:35:34,576 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:35:34,618 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:35:34,619 - INFO - 배치 57 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 57/5225 [14:29<33:50:34, 23.57s/it]2025-05-21 01:35:35,377 - INFO - 배치 58/5225 처리 중... (인덱스 464)
# 2025-05-21 01:35:35,378 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 58/90)
# 2025-05-21 01:35:36,071 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:35:36,087 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:35:36,087 - INFO - 배치 58 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 58/5225 [14:31<24:17:00, 16.92s/it]2025-05-21 01:35:36,767 - INFO - 배치 59/5225 처리 중... (인덱스 465)
# 2025-05-21 01:35:36,768 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 59/90)
# 2025-05-21 01:35:37,488 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:35:37,503 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:35:37,504 - INFO - 배치 59 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 59/5225 [14:32<17:38:58, 12.30s/it]2025-05-21 01:35:38,286 - INFO - 배치 60/5225 처리 중... (인덱스 466)
# 2025-05-21 01:35:38,286 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 60/90)
# 2025-05-21 01:35:38,975 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:35:38,991 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:35:38,992 - INFO - 배치 60 벡터 스토어에 추가 완료
# 2025-05-21 01:35:38,998 - INFO - 벡터 스토어 저장 완료: 인덱스 467
# 배치 처리 중:   1%|          | 60/5225 [14:34<12:59:14,  9.05s/it]2025-05-21 01:35:39,762 - INFO - 배치 61/5225 처리 중... (인덱스 467)
# 2025-05-21 01:35:39,763 - INFO - 분당 요청 한도에 도달했습니다. 56.0초 대기 중...
# 2025-05-21 01:36:35,758 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 61/90)
# 2025-05-21 01:36:36,879 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:36:36,925 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:36:36,926 - INFO - 배치 61 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 61/5225 [15:31<33:57:01, 23.67s/it]2025-05-21 01:36:37,533 - INFO - 배치 62/5225 처리 중... (인덱스 468)
# 2025-05-21 01:36:37,534 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 62/90)
# 2025-05-21 01:36:38,251 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:36:38,268 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:36:38,269 - INFO - 배치 62 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 62/5225 [15:33<24:26:05, 17.04s/it]2025-05-21 01:36:39,100 - INFO - 배치 63/5225 처리 중... (인덱스 469)
# 2025-05-21 01:36:39,101 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 63/90)
# 2025-05-21 01:36:39,832 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:36:39,850 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:36:39,851 - INFO - 배치 63 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 63/5225 [15:35<17:50:50, 12.45s/it]2025-05-21 01:36:40,835 - INFO - 배치 64/5225 처리 중... (인덱스 470)
# 2025-05-21 01:36:40,836 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 64/90)
# 2025-05-21 01:36:41,553 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:36:41,570 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:36:41,571 - INFO - 배치 64 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 64/5225 [15:36<13:03:44,  9.11s/it]2025-05-21 01:36:42,165 - INFO - 배치 65/5225 처리 중... (인덱스 471)
# 2025-05-21 01:36:42,165 - INFO - 분당 요청 한도에 도달했습니다. 55.6초 대기 중...
# 2025-05-21 01:37:37,759 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 65/90)
# 2025-05-21 01:37:39,251 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:37:39,296 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:37:39,297 - INFO - 배치 65 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 65/5225 [16:34<34:07:29, 23.81s/it]2025-05-21 01:37:40,264 - INFO - 배치 66/5225 처리 중... (인덱스 472)
# 2025-05-21 01:37:40,265 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 66/90)
# 2025-05-21 01:37:41,000 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:37:41,018 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:37:41,018 - INFO - 배치 66 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 66/5225 [16:36<24:30:58, 17.11s/it]2025-05-21 01:37:41,737 - INFO - 배치 67/5225 처리 중... (인덱스 473)
# 2025-05-21 01:37:41,738 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 67/90)
# 2025-05-21 01:37:42,462 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:37:42,479 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:37:42,480 - INFO - 배치 67 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 67/5225 [16:37<17:51:26, 12.46s/it]2025-05-21 01:37:43,364 - INFO - 배치 68/5225 처리 중... (인덱스 474)
# 2025-05-21 01:37:43,365 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 68/90)
# 2025-05-21 01:37:44,068 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:37:44,085 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:37:44,086 - INFO - 배치 68 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 68/5225 [16:39<13:06:26,  9.15s/it]2025-05-21 01:37:44,783 - INFO - 배치 69/5225 처리 중... (인덱스 475)
# 2025-05-21 01:37:44,783 - INFO - 분당 요청 한도에 도달했습니다. 55.0초 대기 중...
# 2025-05-21 01:38:39,761 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 69/90)
# 2025-05-21 01:38:41,668 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:38:41,754 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:38:41,755 - INFO - 배치 69 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 69/5225 [17:36<33:54:41, 23.68s/it]2025-05-21 01:38:42,358 - INFO - 배치 70/5225 처리 중... (인덱스 476)
# 2025-05-21 01:38:42,359 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 70/90)
# 2025-05-21 01:38:43,191 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:38:43,228 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:38:43,229 - INFO - 배치 70 벡터 스토어에 추가 완료
# 2025-05-21 01:38:43,234 - INFO - 벡터 스토어 저장 완료: 인덱스 477
# 배치 처리 중:   1%|▏         | 70/5225 [17:38<24:25:48, 17.06s/it]2025-05-21 01:38:43,980 - INFO - 배치 71/5225 처리 중... (인덱스 477)
# 2025-05-21 01:38:43,981 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 71/90)
# 2025-05-21 01:38:44,823 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:38:44,859 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:38:44,859 - INFO - 배치 71 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 71/5225 [17:40<17:51:22, 12.47s/it]2025-05-21 01:38:45,746 - INFO - 배치 72/5225 처리 중... (인덱스 478)
# 2025-05-21 01:38:45,747 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 72/90)
# 2025-05-21 01:38:46,575 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:38:46,612 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:38:46,612 - INFO - 배치 72 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 72/5225 [17:41<13:07:43,  9.17s/it]2025-05-21 01:38:47,218 - INFO - 배치 73/5225 처리 중... (인덱스 479)
# 2025-05-21 01:38:47,218 - INFO - 분당 요청 한도에 도달했습니다. 54.5초 대기 중...
# 2025-05-21 01:39:41,762 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 73/90)
# 2025-05-21 01:39:43,625 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:39:43,711 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:39:43,712 - INFO - 배치 73 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 73/5225 [18:38<33:40:53, 23.54s/it]2025-05-21 01:39:44,267 - INFO - 배치 74/5225 처리 중... (인덱스 480)
# 2025-05-21 01:39:44,268 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 74/90)
# 2025-05-21 01:39:45,103 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:39:45,136 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:39:45,136 - INFO - 배치 74 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 74/5225 [18:40<24:14:10, 16.94s/it]2025-05-21 01:39:45,814 - INFO - 배치 75/5225 처리 중... (인덱스 481)
# 2025-05-21 01:39:45,814 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 75/90)
# 2025-05-21 01:39:46,618 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:39:46,652 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:39:46,653 - INFO - 배치 75 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 75/5225 [18:41<17:41:21, 12.37s/it]2025-05-21 01:39:47,507 - INFO - 배치 76/5225 처리 중... (인덱스 482)
# 2025-05-21 01:39:47,507 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 76/90)
# 2025-05-21 01:39:48,344 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:39:48,379 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:39:48,379 - INFO - 배치 76 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 76/5225 [18:43<13:03:25,  9.13s/it]2025-05-21 01:39:49,085 - INFO - 배치 77/5225 처리 중... (인덱스 483)
# 2025-05-21 01:39:49,085 - INFO - 분당 요청 한도에 도달했습니다. 54.7초 대기 중...
# 2025-05-21 01:40:43,763 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 77/90)
# 2025-05-21 01:40:44,749 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:40:44,828 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:40:44,829 - INFO - 배치 77 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 77/5225 [19:39<33:22:43, 23.34s/it]2025-05-21 01:40:45,590 - INFO - 배치 78/5225 처리 중... (인덱스 484)
# 2025-05-21 01:40:45,590 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 78/90)
# 2025-05-21 01:40:46,402 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:40:46,433 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:40:46,434 - INFO - 배치 78 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 78/5225 [19:41<23:56:56, 16.75s/it]2025-05-21 01:40:46,963 - INFO - 배치 79/5225 처리 중... (인덱스 485)
# 2025-05-21 01:40:46,963 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 79/90)
# 2025-05-21 01:40:47,782 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:40:47,814 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:40:47,815 - INFO - 배치 79 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 79/5225 [19:42<17:20:42, 12.13s/it]2025-05-21 01:40:48,324 - INFO - 배치 80/5225 처리 중... (인덱스 486)
# 2025-05-21 01:40:48,325 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 80/90)
# 2025-05-21 01:40:49,134 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:40:49,165 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:40:49,166 - INFO - 배치 80 벡터 스토어에 추가 완료
# 2025-05-21 01:40:49,171 - INFO - 벡터 스토어 저장 완료: 인덱스 487
# 배치 처리 중:   2%|▏         | 80/5225 [19:44<12:51:01,  8.99s/it]2025-05-21 01:40:49,984 - INFO - 배치 81/5225 처리 중... (인덱스 487)
# 2025-05-21 01:40:49,984 - INFO - 분당 요청 한도에 도달했습니다. 55.8초 대기 중...
# 2025-05-21 01:41:45,764 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 81/90)
# 2025-05-21 01:41:47,648 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:41:47,737 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:41:47,738 - INFO - 배치 81 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 81/5225 [20:42<34:09:44, 23.91s/it]2025-05-21 01:41:48,697 - INFO - 배치 82/5225 처리 중... (인덱스 488)
# 2025-05-21 01:41:48,699 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 2/4, 일일 요청: 82/90)
# 2025-05-21 01:41:49,530 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:41:49,566 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:41:49,567 - INFO - 배치 82 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 82/5225 [20:44<24:36:31, 17.23s/it]2025-05-21 01:41:50,330 - INFO - 배치 83/5225 처리 중... (인덱스 489)
# 2025-05-21 01:41:50,330 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 일일 요청: 83/90)
# 2025-05-21 01:41:51,152 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:41:51,190 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:41:51,191 - INFO - 배치 83 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 83/5225 [20:46<17:51:31, 12.50s/it]2025-05-21 01:41:51,814 - INFO - 배치 84/5225 처리 중... (인덱스 490)
# 2025-05-21 01:41:51,814 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 84/90)
# 2025-05-21 01:41:52,645 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:41:52,680 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:41:52,681 - INFO - 배치 84 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 84/5225 [20:47<13:11:11,  9.23s/it]2025-05-21 01:41:53,419 - INFO - 배치 85/5225 처리 중... (인덱스 491)
# 2025-05-21 01:41:53,421 - INFO - 분당 요청 한도에 도달했습니다. 54.3초 대기 중...
# 2025-05-21 01:42:47,765 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 85/90)
# 2025-05-21 01:42:49,284 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:42:49,332 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:42:49,332 - INFO - 배치 85 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 85/5225 [21:44<33:33:19, 23.50s/it]2025-05-21 01:42:50,213 - INFO - 배치 86/5225 처리 중... (인덱스 492)
# 2025-05-21 01:42:50,214 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 86/90)
# 2025-05-21 01:42:50,927 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:42:50,943 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:42:50,945 - INFO - 배치 86 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 86/5225 [21:46<24:08:58, 16.92s/it]2025-05-21 01:42:51,767 - INFO - 배치 87/5225 처리 중... (인덱스 493)
# 2025-05-21 01:42:51,768 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 87/90)
# 2025-05-21 01:42:52,505 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:42:52,523 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:42:52,523 - INFO - 배치 87 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 87/5225 [21:47<17:38:31, 12.36s/it]2025-05-21 01:42:53,497 - INFO - 배치 88/5225 처리 중... (인덱스 494)
# 2025-05-21 01:42:53,498 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 88/90)
# 2025-05-21 01:42:54,207 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:42:54,225 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:42:54,226 - INFO - 배치 88 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 88/5225 [21:49<13:01:22,  9.13s/it]2025-05-21 01:42:55,076 - INFO - 배치 89/5225 처리 중... (인덱스 495)
# 2025-05-21 01:42:55,076 - INFO - 분당 요청 한도에 도달했습니다. 54.7초 대기 중...
# 2025-05-21 01:43:49,766 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 89/90)
# 2025-05-21 01:43:50,667 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:43:50,708 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:43:50,709 - INFO - 배치 89 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 89/5225 [22:45<33:08:44, 23.23s/it]2025-05-21 01:43:51,224 - INFO - 배치 90/5225 처리 중... (인덱스 496)
# 2025-05-21 01:43:51,225 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 90/90)
# 2025-05-21 01:43:51,922 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 01:43:51,937 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 01:43:51,938 - INFO - 배치 90 벡터 스토어에 추가 완료
# 2025-05-21 01:43:51,943 - INFO - 벡터 스토어 저장 완료: 인덱스 497
# 배치 처리 중:   2%|▏         | 90/5225 [22:47<23:55:10, 16.77s/it]2025-05-21 01:43:52,911 - INFO - 배치 91/5225 처리 중... (인덱스 497)
# 2025-05-21 01:43:52,912 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 91/90)
# 2025-05-21 01:43:53,106 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 429 Too Many Requests"
# 2025-05-21 01:43:53,107 - WARNING - 임베딩 생성 중 오류 발생 (시도 1/5): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# 2025-05-21 01:43:53,107 - INFO - 11.2초 후 재시도합니다...
# 2025-05-21 01:44:04,312 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 일일 요청: 92/90)
# 2025-05-21 01:44:04,615 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 429 Too Many Requests"
# 2025-05-21 01:44:04,616 - WARNING - 임베딩 생성 중 오류 발생 (시도 2/5): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# 2025-05-21 01:44:04,616 - INFO - 24.1초 후 재시도합니다...
# 2025-05-21 01:44:28,708 - INFO - 분당 요청 한도에 도달했습니다. 23.1초 대기 중...
# 배치 처리 중:   2%|▏         | 90/5225 [23:46<22:36:02, 15.84s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 831
#     828             logger.info(f"결과 {i+1} - {doc.metadata.get('document_type')}: {doc.page_content[:150]}...")
#     830 if __name__ == "__main__":
# --> 831     main()
#
# Cell In[1], line 814, in main()
#     812 # 벡터 스토어 생성
#     813 logger.info("벡터 스토어 구축 중...")
# --> 814 vectorstore = vs_builder.create_vector_store(documents, batch_size=1)
#     816 if vectorstore:
#     817     logger.info("벡터 스토어 구축 완료!")
#
# Cell In[1], line 653, in MedicalVectorStore.create_vector_store(self, documents, store_name, batch_size)
#     650 metadatas = [doc.metadata for doc in batch]
#     652 # 직접 임베딩 생성
# --> 653 embeddings = self._embed_documents(texts)
#     655 # 임베딩 결과 디버그
#     656 logger.info(f"임베딩 결과: 길이={len(embeddings)}, 차원={len(embeddings[0])}")
#
# Cell In[1], line 122, in MedicalVectorStore._embed_documents(self, texts, max_retries, retry_delay)
#     119 while retries < max_retries:
#     120     try:
#     121         # 속도 제한 관리
# --> 122         self._wait_for_rate_limit()
#     124         # 현재 시간 기록
#     125         current_time = time.time()
#
# Cell In[1], line 111, in MedicalVectorStore._wait_for_rate_limit(self)
#     109 wait_time = (oldest_request + 60) - current_time + 2  # 2초 버퍼 추가
#     110 logger.info(f"분당 요청 한도에 도달했습니다. {wait_time:.1f}초 대기 중...")
# --> 111 time.sleep(max(wait_time, 0))
#     112 return self._wait_for_rate_limit()
#
# KeyboardInterrupt:

# %% [markdown]
# 1X
# AIzaSyC9YAhSTdtK4ln-d3cfhTNZG2wPHxpPefw
# 2X
# AIzaSyAnowS98saPDRSYMlsK6kKNLuFDN9CcMu0
# 3x
# AIzaSyAv191QoomogGWKZmEPt9xfMWUjTu84_nU
# 4x
# AIzaSyDgoKVgiZTgfU4tWn36kj7EXLBMuxaMscQ,AIzaSyBBxCsZCpYHtDQr9DjAldp_CElT5Gjn-aQ,AIzaSyDVFsuU6213Vt2QUqSJabZXfx_0ZH-bqB0,AIzaSyA9Vqa3pudBOJt5ceoEsaCxYYENa11vltc,AIzaSyAIMv1uNZTgdbZ5taAQ_BjGCb9uQzjYz1g,AIzaSyCndJCfaKSc0hU7FjNocNPTJT7bH1R1gvc,AIzaSyCoFHBvN-MOQoW3hAXWlpstddRWkOhVw_c

# %% [markdown]
# AIzaSyCX5X19glBVjEMjfzKmVQUXz7vha2eHvt4,AIzaSyD8khCNEFicOQcO5AcKMQZrWww2G40TYQY,AIzaSyCvBnxbKYFdi-Jt98EuN_SyLAcBt0Lju6U,AIzaSyDUKEF_qXj6H0e8JckAGa6-3oOEu2S7jx8,AIzaSyAWHI0fiVStupmAB2O1gtojTVDCooKPLKE,AIzaSyDw_GBYnhqzOcM49N0Fm78A0OSfUqDgPIA,AIzaSyB6qRgKJmjsC7mFJYOMf1V7UzFHRJTzC24,AIzaSyD6CoaZHBAYzrGbuFQT5B7QrGQdEqv2pL8,AIzaSyBWT2Rxu6-NrzVoiFN4CccjlBygXFWg-y8,AIzaSyCYNMZ7OngDEsr0hmburOjBRvLeUMf9NZo,AIzaSyCYNMZ7OngDEsr0hmburOjBRvLeUMf9NZo

# %% [markdown]
# # test2

# %%
import os
import json
import logging
import time
from datetime import datetime
from pathlib import Path
import concurrent.futures
import torch
from tqdm import tqdm
import random
from google import genai

# 로깅 설정
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

class MedicalVectorStore:
    """
    의료 데이터를 위한 벡터 스토어 구축 클래스
    """
    def __init__(self, data_path="./medical_data", vector_store_path="./vector_stores", use_gpu=True, api_keys=None):
        """
        초기화 함수
        
        Args:
            data_path: 의료 데이터가 저장된 경로
            vector_store_path: 벡터 스토어를 저장할 경로
            use_gpu: GPU 사용 여부
            api_keys: Google API 키 리스트
        """
        self.data_path = Path(data_path)
        self.vector_store_path = Path(vector_store_path)
        
        # API 키 리스트로 변경
        if api_keys is None or not api_keys:
            raise ValueError("적어도 하나 이상의 Google API 키가 필요합니다.")
        
        # 문자열로 전달된 경우 리스트로 변환
        if isinstance(api_keys, str):
            self.api_keys = [api_keys]
        else:
            self.api_keys = api_keys
        
        self.current_api_key_index = 0  # 현재 사용 중인 API 키 인덱스
        self.api_key = self.api_keys[self.current_api_key_index]  # 현재 사용 중인 API 키
        
        # 기본 디렉토리 생성
        self.data_path.mkdir(parents=True, exist_ok=True)
        self.vector_store_path.mkdir(parents=True, exist_ok=True)

        # GPU 사용 여부 확인
        self.device = "cuda" if use_gpu and torch.cuda.is_available() else "cpu"
        logger.info(f"Using device: {self.device}")

        # Google API 클라이언트 직접 생성
        self.client = genai.Client(api_key=self.api_key)
        
        # API 속도 제한 관리를 위한 변수
        self.request_timestamps = []
        self.max_requests_per_minute = 4
        
        # API 키 상태 추적 (하루 제한 대신 키당 카운트만 유지)
        self.api_key_status = {key: {"active": True, "count": 0} for key in self.api_keys}
        

        # API 키 확인
        if not self.api_key:
            raise ValueError("Google API 키가 필요합니다.")

        # Google API 클라이언트 직접 생성
        self.client = genai.Client(api_key=self.api_key)
        
        # API 속도 제한 관리를 위한 변수
        self.request_timestamps = []
        self.max_requests_per_minute = 4
        self.daily_request_count = 0
        self.daily_reset_time = time.time() + 86400

        # 커스텀 임베딩 클래스 생성 (LangChain 호환)
        class GeminiEmbeddings:
            def __init__(self, client):
                self.client = client
            
            def embed_documents(self, texts):
                # 이 메서드는 실제로 사용되지 않음 (embed_query만 사용)
                raise NotImplementedError("이 메서드는 사용하지 않습니다.")
            
            def embed_query(self, text):
                # 쿼리 임베딩만 필요 (검색 시)
                result = self.client.models.embed_content(
                    model="models/gemini-embedding-exp-03-07",  # 문서 임베딩과 동일한 모델 사용
                    contents=[text],
                    config={"task_type": "retrieval_query"}
                )
                return result.embeddings[0].values
        
        # 커스텀 임베딩 인스턴스 생성
        self.embeddings_for_search = GeminiEmbeddings(self.client)

        from langchain.text_splitter import RecursiveCharacterTextSplitter

        # 문서 분할기 설정
        self.text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=500,
            chunk_overlap=100,
            separators=["\n\n", "\n", ". ", " ", ""],
            length_function=len
        )

    def _switch_to_next_api_key(self):
        """다음 사용 가능한 API 키로 전환"""
        # 현재 키를 비활성화
        self.api_key_status[self.api_key]["active"] = False
        logger.warning(f"API 키 [{self.api_key[:8]}...] 소진됨 (100회 사용). 다음 키로 전환 시도...")
        
        # 다음 사용 가능한 키 찾기
        original_index = self.current_api_key_index
        found_active_key = False
        
        for _ in range(len(self.api_keys)):
            self.current_api_key_index = (self.current_api_key_index + 1) % len(self.api_keys)
            candidate_key = self.api_keys[self.current_api_key_index]
            
            if self.api_key_status[candidate_key]["active"]:
                self.api_key = candidate_key
                self.client = genai.Client(api_key=self.api_key)
                
                # 새 키로 카운터 초기화 (분당 제한만 초기화)
                self.request_timestamps = []
                
                logger.info(f"새 API 키 [{self.api_key[:8]}...](으)로 전환 성공!")
                found_active_key = True
                break
        
        if not found_active_key:
            logger.error("모든 API 키가 소진되었습니다! 계속할 수 없습니다.")
            raise RuntimeError("모든 API 키가 소진되었습니다. 추가 API 키를 제공하세요.")
        
    def _wait_for_rate_limit(self):
        """API 요청 속도 제한을 관리하는 메서드"""
        current_time = time.time()
        
        # API 키당 요청 한도 확인 (하루 제한 대신 키당 고정 요청 수)
        if self.api_key_status[self.api_key]["count"] >= 100:  # 키당 100회로 제한
            # 현재 키 소진 여부 확인
            if len(self.api_keys) > 1:  # 여러 개의 키가 있는 경우
                self._switch_to_next_api_key()
                return self._wait_for_rate_limit()  # 새 키로 다시 시도
            else:
                # 마지막 키인 경우 오류 발생
                logger.error("모든 API 키가 할당된 요청 한도에 도달했습니다!")
                raise RuntimeError("모든 API 키가 할당된 요청 한도(키당 100회)에 도달했습니다. 추가 API 키를 제공하세요.")
        
        # 분당 요청 제한 관리 (이 부분은 여전히 필요)
        self.request_timestamps = [t for t in self.request_timestamps if current_time - t < 60]
        
        if len(self.request_timestamps) >= self.max_requests_per_minute:
            oldest_request = min(self.request_timestamps)
            wait_time = (oldest_request + 60) - current_time + 2  # 2초 버퍼 추가
            logger.info(f"분당 요청 한도에 도달했습니다. {wait_time:.1f}초 대기 중...")
            time.sleep(max(wait_time, 0))
            return self._wait_for_rate_limit()

    def _embed_documents(self, texts, max_retries=5, retry_delay=10):
        """
        직접 Google API를 호출하여 임베딩 생성
        API 키 소진 시 자동으로 다음 키로 전환
        """
        retries = 0
        while retries < max_retries:
            try:
                # 속도 제한 관리
                self._wait_for_rate_limit()
                
                # 현재 시간 기록
                current_time = time.time()
                self.request_timestamps.append(current_time)
                self.daily_request_count += 1
                self.api_key_status[self.api_key]["count"] += 1
                
                logger.info(f"임베딩 API 호출 (배치 크기: {len(texts)}, 분당 요청: {len(self.request_timestamps)}/{self.max_requests_per_minute}, 키 사용량: {self.api_key_status[self.api_key]['count']}/100)")
                
                # 직접 API 호출
                result = self.client.models.embed_content(
                    model="models/gemini-embedding-exp-03-07",  # 보다 안정적인 모델 사용
                    contents=texts,
                    config={"task_type": "retrieval_document"}
                )
                
                # 결과 추출
                embeddings = [embedding.values for embedding in result.embeddings]
                
                return embeddings
            except Exception as e:
                error_msg = str(e).lower()
                
                # API 키 한도 초과 오류인지 확인
                if "quota" in error_msg or "limit" in error_msg or "rate" in error_msg:
                    logger.warning(f"API 키 한도 초과 오류: {e}")
                    if len(self.api_keys) > 1:  # 여러 개의 키가 있는 경우
                        self._switch_to_next_api_key()
                        retries = 0  # 새 키로 재시도 카운트 초기화
                        continue
                
                logger.warning(f"임베딩 생성 중 오류 발생 (시도 {retries+1}/{max_retries}): {e}")
                retries += 1
                if retries >= max_retries:
                    logger.error(f"최대 재시도 횟수 초과. 실패: {e}")
                    raise
                wait_time = retry_delay * (2 ** (retries - 1)) + random.uniform(1, 5)
                logger.info(f"{wait_time:.1f}초 후 재시도합니다...")
                time.sleep(wait_time)

    def load_medical_data(self, file_pattern="*_patients.json"):
        """
        의료 데이터 로드 - 병렬 처리
        """
        import glob

        data_files = list(self.data_path.glob(file_pattern))

        if not data_files:
            logger.warning(f"No files matching {file_pattern} found in {self.data_path}")
            return []

        # 병렬 처리로 여러 파일 동시 로드
        documents = []

        with concurrent.futures.ThreadPoolExecutor(max_workers=min(len(data_files), os.cpu_count())) as executor:
            future_to_file = {
                executor.submit(self._load_single_file, file_path): file_path
                for file_path in data_files
            }

            for future in tqdm(concurrent.futures.as_completed(future_to_file),
                               total=len(future_to_file),
                               desc="Loading files"):
                file_docs = future.result()
                if file_docs:
                    documents.extend(file_docs)

        logger.info(f"Loaded {len(documents)} total documents from medical data")
        return documents

    def _load_single_file(self, file_path):
        """
        단일 파일 로드 (병렬 처리용) - 테스트를 위해 환자 수 제한 가능
        """
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                patients = json.load(f)

            department = file_path.stem.replace("_patients", "")
            
            # 테스트를 위해 환자 수 제한 (전체 데이터 처리가 부담스러우면 주석 해제)
            # patients = patients[:5]  # 각 파일에서 5명만 처리
            
            logger.info(f"Loading {len(patients)} patients from {department} department")

            # 각 환자 정보를 문서로 변환
            docs = []
            for patient in patients:
                docs.extend(self._convert_patient_to_documents(patient, department))

            return docs

        except Exception as e:
            logger.error(f"Error loading {file_path}: {e}")
            return []


    def _convert_patient_to_documents(self, patient, department):
            """
            환자 정보를 여러 개의 문서로 변환 (세분화된 정보)
            """
            from langchain.schema import Document

            documents = []

            # 환자 기본 정보 문서
            basic_info = f"""
            환자 ID: {patient['id']}
            이름: {patient['name']}
            성별: {patient['gender']}
            나이: {patient['age']}
            생년월일: {patient['birthdate']}
            혈액형: {patient.get('blood_type', '정보 없음')}
            키: {patient.get('height', '정보 없음')} cm
            체중: {patient.get('weight', '정보 없음')} kg
            BMI: {patient.get('bmi', '정보 없음')}
            주소: {patient.get('address', '정보 없음')}
            전화번호: {patient.get('phone', '정보 없음')}
            보험: {patient.get('insurance', '정보 없음')}
            진료과: {department}
            """

            if patient.get('allergies'):
                basic_info += f"\n알레르기: {', '.join(patient['allergies'])}"

            if patient.get('smoking'):
                basic_info += f"\n흡연: {patient['smoking']['status']}"
                if patient['smoking'].get('details'):
                    basic_info += f" ({patient['smoking']['details']})"

            if patient.get('alcohol'):
                basic_info += f"\n음주: {patient['alcohol']['status']}"
                if patient['alcohol'].get('details'):
                    basic_info += f" ({patient['alcohol']['details']})"

            documents.append(Document(
                page_content=basic_info.strip(),
                metadata={
                    "patient_id": patient['id'],
                    "name": patient['name'],
                    "gender": patient['gender'],
                    "age": patient['age'],
                    "department": department,
                    "document_type": "basic_info"
                }
            ))

            # 진단 정보 문서
            if patient.get('diagnoses'):
                for i, diagnosis in enumerate(patient['diagnoses']):
                    diagnosis_doc = f"""
                    환자 ID: {patient['id']}
                    이름: {patient['name']}
                    성별: {patient['gender']}
                    나이: {patient['age']}

                    [진단 정보 {i+1}]
                    진단명: {diagnosis['name']}
                    ICD10 코드: {diagnosis.get('icd10', '정보 없음')}
                    진단일: {diagnosis.get('date', '정보 없음')}
                    진단 의사: {diagnosis.get('doctor', '정보 없음')} (ID: {diagnosis.get('doctor_id', '정보 없음')})
                    확신도: {diagnosis.get('confidence', '정보 없음')}
                    상태: {diagnosis.get('status', '정보 없음')}
                    중증도: {diagnosis.get('severity', '정보 없음')}
                    메모: {diagnosis.get('memo', '정보 없음')}
                    증상: {', '.join(diagnosis.get('symptoms', ['정보 없음']))}
                    """

                    documents.append(Document(
                        page_content=diagnosis_doc.strip(),
                        metadata={
                            "patient_id": patient['id'],
                            "name": patient['name'],
                            "gender": patient['gender'],
                            "age": patient['age'],
                            "department": department,
                            "document_type": "diagnosis",
                            "diagnosis_name": diagnosis['name'],
                            "diagnosis_date": diagnosis.get('date', ''),
                            "diagnosis_status": diagnosis.get('status', '')
                        }
                    ))

            # 약물 정보 문서
            if patient.get('medications'):
                for i, medication in enumerate(patient['medications']):
                    medication_doc = f"""
                    환자 ID: {patient['id']}
                    이름: {patient['name']}
                    성별: {patient['gender']}
                    나이: {patient['age']}

                    [약물 정보 {i+1}]
                    약물명: {medication['medication']}
                    약물 분류: {medication.get('class', '정보 없음')}
                    처방일: {medication.get('prescription_date', '정보 없음')}
                    처방 기간: {medication.get('duration_days', '정보 없음')}일
                    용량: {medication.get('dosage', '정보 없음')}
                    빈도: {medication.get('frequency', '정보 없음')}
                    재처방 횟수: {medication.get('refill', '정보 없음')}
                    처방 의사: {medication.get('doctor', '정보 없음')} (ID: {medication.get('doctor_id', '정보 없음')})
                    관련 진단: {medication.get('related_diagnosis', '정보 없음')}
                    특별 지시사항: {medication.get('special_instructions', '정보 없음')}
                    """

                    documents.append(Document(
                        page_content=medication_doc.strip(),
                        metadata={
                            "patient_id": patient['id'],
                            "name": patient['name'],
                            "gender": patient['gender'],
                            "age": patient['age'],
                            "department": department,
                            "document_type": "medication",
                            "medication_name": medication['medication'],
                            "medication_class": medication.get('class', ''),
                            "related_diagnosis": medication.get('related_diagnosis', '')
                        }
                    ))

            # 검사 결과 문서
            if patient.get('lab_results'):
                for i, lab in enumerate(patient['lab_results']):
                    lab_doc = f"""
                    환자 ID: {patient['id']}
                    이름: {patient['name']}
                    성별: {patient['gender']}
                    나이: {patient['age']}

                    [검사 결과 {i+1}]
                    검사일: {lab.get('date', '정보 없음')}
                    검사 유형: {lab.get('test_type', '정보 없음')}
                    검사 요청 의사: {lab.get('ordering_doctor', '정보 없음')} (ID: {lab.get('ordering_doctor_id', '정보 없음')})
                    검사 ID: {lab.get('lab_id', '정보 없음')}
                    검체 채취 시간: {lab.get('collection_time', '정보 없음')}
                    보고 시간: {lab.get('report_time', '정보 없음')}

                    결과 항목:
                    """

                    for test_name, test_result in lab.get('results', {}).items():
                        lab_doc += f"""
                        - {test_name}: {test_result.get('value', '정보 없음')} {test_result.get('unit', '')}
                        (정상 범위: {test_result.get('normal_range', '정보 없음')})
                        {test_result.get('flag', '')}
                        """

                    if lab.get('interpretation'):
                        lab_doc += f"\n해석: {lab['interpretation']}"

                    documents.append(Document(
                        page_content=lab_doc.strip(),
                        metadata={
                            "patient_id": patient['id'],
                            "name": patient['name'],
                            "gender": patient['gender'],
                            "age": patient['age'],
                            "department": department,
                            "document_type": "lab_result",
                            "lab_date": lab.get('date', ''),
                            "test_type": lab.get('test_type', '')
                        }
                    ))

            # 영상 검사 문서
            if patient.get('imaging_studies'):
                for i, study in enumerate(patient['imaging_studies']):
                    imaging_doc = f"""
                    환자 ID: {patient['id']}
                    이름: {patient['name']}
                    성별: {patient['gender']}
                    나이: {patient['age']}

                    [영상 검사 {i+1}]
                    검사일: {study.get('date', '정보 없음')}
                    검사 유형: {study.get('study_type', '정보 없음')}
                    검사 요청 의사: {study.get('ordering_doctor', '정보 없음')} (ID: {study.get('ordering_doctor_id', '정보 없음')})
                    영상의학과 의사: {study.get('radiologist', '정보 없음')}
                    검사 ID: {study.get('study_id', '정보 없음')}

                    소견: {study.get('findings', '정보 없음')}
                    판독: {study.get('impression', '정보 없음')}
                    추천: {study.get('recommendation', '정보 없음')}
                    """

                    documents.append(Document(
                        page_content=imaging_doc.strip(),
                        metadata={
                            "patient_id": patient['id'],
                            "name": patient['name'],
                            "gender": patient['gender'],
                            "age": patient['age'],
                            "department": department,
                            "document_type": "imaging_study",
                            "study_date": study.get('date', ''),
                            "study_type": study.get('study_type', '')
                        }
                    ))

            # 시술 및 수술 문서
            if patient.get('procedures'):
                for i, procedure in enumerate(patient['procedures']):
                    procedure_doc = f"""
                    환자 ID: {patient['id']}
                    이름: {patient['name']}
                    성별: {patient['gender']}
                    나이: {patient['age']}

                    [시술/수술 {i+1}]
                    시술일: {procedure.get('date', '정보 없음')}
                    시술명: {procedure.get('name', '정보 없음')}
                    설명: {procedure.get('description', '정보 없음')}
                    시술 의사: {procedure.get('performing_doctor', '정보 없음')} (ID: {procedure.get('performing_doctor_id', '정보 없음')})
                    시술 ID: {procedure.get('procedure_id', '정보 없음')}
                    위치: {procedure.get('location', '정보 없음')}
                    마취: {procedure.get('anesthesia', '정보 없음')}
                    소요 시간: {procedure.get('duration_minutes', '정보 없음')}분
                    결과: {procedure.get('outcome', '정보 없음')}
                    """

                    if procedure.get('complications'):
                        procedure_doc += f"\n합병증: {', '.join(procedure['complications'])}"

                    procedure_doc += f"\n추적 관찰: {procedure.get('follow_up', '정보 없음')}"

                    documents.append(Document(
                        page_content=procedure_doc.strip(),
                        metadata={
                            "patient_id": patient['id'],
                            "name": patient['name'],
                            "gender": patient['gender'],
                            "age": patient['age'],
                            "department": department,
                            "document_type": "procedure",
                            "procedure_date": procedure.get('date', ''),
                            "procedure_name": procedure.get('name', ''),
                            "outcome": procedure.get('outcome', '')
                        }
                    ))

            # 진료 기록 문서
            if patient.get('visits'):
                for i, visit in enumerate(patient['visits']):
                    visit_doc = f"""
                    환자 ID: {patient['id']}
                    이름: {patient['name']}
                    성별: {patient['gender']}
                    나이: {patient['age']}

                    [진료 기록 {i+1}]
                    방문 ID: {visit.get('visit_id', '정보 없음')}
                    방문일: {visit.get('date', '정보 없음')}
                    방문 시간: {visit.get('time', '정보 없음')}
                    방문 유형: {visit.get('type', '정보 없음')}
                    진료과: {visit.get('department', '정보 없음')}
                    담당 의사: {visit.get('doctor', '정보 없음')} (ID: {visit.get('doctor_id', '정보 없음')})
                    주 호소: {visit.get('chief_complaint', '정보 없음')}

                    활력 징후:
                    수축기 혈압: {visit.get('vital_signs', {}).get('systolic_bp', '정보 없음')} mmHg
                    이완기 혈압: {visit.get('vital_signs', {}).get('diastolic_bp', '정보 없음')} mmHg
                    맥박: {visit.get('vital_signs', {}).get('pulse', '정보 없음')} bpm
                    체온: {visit.get('vital_signs', {}).get('temperature', '정보 없음')} °C
                    호흡수: {visit.get('vital_signs', {}).get('respiratory_rate', '정보 없음')} /분
                    산소포화도: {visit.get('vital_signs', {}).get('oxygen_saturation', '정보 없음')} %
                    """

                    if 'blood_glucose' in visit.get('vital_signs', {}):
                        visit_doc += f"혈당: {visit['vital_signs']['blood_glucose']} mg/dL\n"

                    visit_doc += f"""
                    임상 노트:
                    주관적(S): {visit.get('clinical_note', {}).get('subjective', '정보 없음')}
                    객관적(O): {visit.get('clinical_note', {}).get('objective', '정보 없음')}
                    평가(A): {visit.get('clinical_note', {}).get('assessment', '정보 없음')}
                    계획(P): {visit.get('clinical_note', {}).get('plan', '정보 없음')}

                    진료 시간: {visit.get('duration_minutes', '정보 없음')}분
                    """

                    if visit.get('next_appointment'):
                        visit_doc += f"다음 예약: {visit['next_appointment']}"

                    documents.append(Document(
                        page_content=visit_doc.strip(),
                        metadata={
                            "patient_id": patient['id'],
                            "name": patient['name'],
                            "gender": patient['gender'],
                            "age": patient['age'],
                            "department": department,
                            "document_type": "visit",
                            "visit_date": visit.get('date', ''),
                            "visit_type": visit.get('type', ''),
                            "chief_complaint": visit.get('chief_complaint', '')
                        }
                    ))

            # 통합 문서 (전체 환자 기록을 하나의 문서로)
            integrated_doc = f"""
            [환자 통합 기록]
            환자 ID: {patient['id']}
            이름: {patient['name']}
            성별: {patient['gender']}
            나이: {patient['age']}
            생년월일: {patient['birthdate']}
            진료과: {department}

            [진단 요약]
            """

            if patient.get('diagnoses'):
                for diagnosis in patient['diagnoses']:
                    integrated_doc += f"""
                    - {diagnosis['name']} ({diagnosis.get('date', '날짜 없음')})
                    상태: {diagnosis.get('status', '정보 없음')}, 중증도: {diagnosis.get('severity', '정보 없음')}
                    """
            else:
                integrated_doc += "진단 정보 없음\n"

            integrated_doc += "\n[약물 요약]\n"
            if patient.get('medications'):
                for med in patient['medications']:
                    integrated_doc += f"""
                    - {med['medication']} {med.get('dosage', '')} {med.get('frequency', '')}
                    처방일: {med.get('prescription_date', '정보 없음')}, 관련 진단: {med.get('related_diagnosis', '정보 없음')}
                    """
            else:
                integrated_doc += "약물 정보 없음\n"

            integrated_doc += "\n[최근 검사 결과 요약]\n"
            if patient.get('lab_results'):
                # 가장 최근 검사 결과만 포함
                recent_lab = max(patient['lab_results'], key=lambda x: x.get('date', ''))
                integrated_doc += f"검사일: {recent_lab.get('date', '정보 없음')}, 검사 유형: {recent_lab.get('test_type', '정보 없음')}\n"

                for test_name, test_result in recent_lab.get('results', {}).items():
                    flag = test_result.get('flag', '')
                    if flag:
                        integrated_doc += f"- {test_name}: {test_result.get('value', '')} {test_result.get('unit', '')} ({flag})\n"
            else:
                integrated_doc += "검사 결과 정보 없음\n"

            integrated_doc += "\n[최근 방문 요약]\n"
            if patient.get('visits'):
                # 가장 최근 방문만 포함
                recent_visit = max(patient['visits'], key=lambda x: x.get('date', ''))
                integrated_doc += f"""
                방문일: {recent_visit.get('date', '정보 없음')}
                주 호소: {recent_visit.get('chief_complaint', '정보 없음')}
                평가: {recent_visit.get('clinical_note', {}).get('assessment', '정보 없음')}
                계획: {recent_visit.get('clinical_note', {}).get('plan', '정보 없음')}
                """
            else:
                integrated_doc += "방문 기록 없음\n"

            documents.append(Document(
                page_content=integrated_doc.strip(),
                metadata={
                    "patient_id": patient['id'],
                    "name": patient['name'],
                    "gender": patient['gender'],
                    "age": patient['age'],
                    "department": department,
                    "document_type": "integrated_record"
                }
            ))

            return documents

    def create_vector_store(self, documents, store_name="medical_vector_store", batch_size=1):
        """
        벡터 스토어 생성 - API 직접 호출 방식
        """
        if not documents:
            logger.warning("벡터 스토어를 생성할 문서가 없습니다.")
            return None

        logger.info(f"{len(documents)}개 문서로 벡터 스토어 생성 중...")

        # 문서를 청크로 분할
        chunks = self.text_splitter.split_documents(documents)
        logger.info(f"총 {len(chunks)}개의 청크 생성")

        from langchain_community.vectorstores import FAISS
        
        # 진행 상황 추적 파일
        store_path = self.vector_store_path / store_name
        store_path.mkdir(parents=True, exist_ok=True)
        progress_file = self.vector_store_path / f"{store_name}_progress.txt"
        start_index = 0
        
        # 진행 상황 파일 확인
        if progress_file.exists():
            try:
                with open(progress_file, "r") as f:
                    start_index = int(f.read().strip())
                logger.info(f"이전 진행 상황 발견, 인덱스 {start_index}부터 재개합니다.")
            except Exception as e:
                logger.warning(f"진행 상황 파일 읽기 실패, 처음부터 시작합니다: {e}")
        
        # 기존 벡터 스토어 확인
        vectorstore = None
        if start_index > 0 and store_path.exists():
            try:
                logger.info(f"기존 벡터 스토어 로드 중: {store_path}")
                vectorstore = FAISS.load_local(
                    store_path,
                    self.embeddings_for_search,
                    allow_dangerous_deserialization=True
                )
                logger.info("기존 벡터 스토어 로드 완료")
            except Exception as e:
                logger.warning(f"기존 벡터 스토어 로드 실패, 새로 시작합니다: {e}")
                start_index = 0
        
        # 청크 처리
        try:
            # 처리할 청크들
            remaining_chunks = chunks[start_index:]
            
            # 배치 생성
            batches = []
            for i in range(0, len(remaining_chunks), batch_size):
                batches.append(remaining_chunks[i:i + batch_size])
            
            logger.info(f"{len(batches)}개의 배치로 처리 예정 (시작 인덱스: {start_index})")
            
            # 각 배치 처리
            for batch_idx, batch in enumerate(tqdm(batches, desc="배치 처리 중")):
                current_index = start_index + batch_idx * batch_size
                logger.info(f"배치 {batch_idx+1}/{len(batches)} 처리 중... (인덱스 {current_index})")
                
                # create_vector_store 메서드 내부의 배치 처리 코드 수정
                try:
                    # 텍스트 추출
                    texts = [doc.page_content for doc in batch]
                    metadatas = [doc.metadata for doc in batch]
                    
                    # 직접 임베딩 생성
                    embeddings = self._embed_documents(texts)
                    
                    # 임베딩 결과 디버그
                    logger.info(f"임베딩 결과: 길이={len(embeddings)}, 차원={len(embeddings[0])}")
                    
                    # 임베딩을 FAISS 포맷으로 변환
                    if batch_idx == 0 and vectorstore is None:
                        # 첫 번째 배치로 벡터 스토어 생성
                        try:
                            vectorstore = FAISS.from_embeddings(
                                text_embeddings=list(zip(texts, embeddings)),
                                embedding=self.embeddings_for_search,
                                metadatas=metadatas
                            )
                            logger.info("첫 번째 배치로 벡터 스토어 생성 완료")
                        except Exception as e:
                            logger.error(f"벡터 스토어 생성 오류: {e}")
                            # 오류 세부 정보 출력
                            import traceback
                            logger.error(traceback.format_exc())
                            raise
                    else:
                        # 기존 벡터 스토어에 추가
                        try:
                            vectorstore.add_embeddings(
                                text_embeddings=list(zip(texts, embeddings)),
                                metadatas=metadatas
                            )
                            logger.info(f"배치 {batch_idx+1} 벡터 스토어에 추가 완료")
                        except Exception as e:
                            logger.error(f"벡터 스토어 추가 오류: {e}")
                            # 오류 세부 정보 출력
                            import traceback
                            logger.error(traceback.format_exc())
                            raise
                    
                    # 진행 상황 업데이트
                    with open(progress_file, "w") as f:
                        f.write(str(current_index + len(batch)))
                    
                    # 10개 배치마다 또는 마지막 배치 후 저장
                    if (batch_idx + 1) % 10 == 0 or batch_idx == len(batches) - 1:
                        try:
                            vectorstore.save_local(store_path)
                            logger.info(f"벡터 스토어 저장 완료: 인덱스 {current_index + len(batch)}")
                        except Exception as e:
                            logger.error(f"벡터 스토어 저장 오류: {e}")
                            import traceback
                            logger.error(traceback.format_exc())
                    
                    # 배치 간 잠시 대기
                    time.sleep(random.uniform(0.5, 1.0))
                    
                except Exception as e:
                    logger.error(f"배치 {batch_idx+1} 처리 중 오류 발생: {e}")
                    # 현재 진행 상태 저장
                    with open(progress_file, "w") as f:
                        f.write(str(current_index))
                    time.sleep(5)  # 오류 후 더 긴 대기
                    continue
            
            # 모든 배치 처리 완료 후 최종 저장
            if vectorstore:
                vectorstore.save_local(store_path)
                logger.info(f"모든 청크 처리 완료! 벡터 스토어가 {store_path}에 저장되었습니다.")
                
                # 진행 상황 파일 삭제
                if progress_file.exists():
                    progress_file.unlink()
                    logger.info("진행 상황 파일 삭제됨")
            
            return vectorstore
                
        except Exception as e:
            logger.error(f"벡터 스토어 생성 중 심각한 오류 발생: {e}")
            return None
    
    def load_vector_store(self, store_name="medical_vector_store"):
        """
        저장된 벡터 스토어 로드
        """
        from langchain_community.vectorstores import FAISS

        store_path = self.vector_store_path / store_name

        if not store_path.exists():
            logger.error(f"벡터 스토어 경로가 존재하지 않습니다: {store_path}")
            return None

        logger.info(f"{store_path}에서 벡터 스토어 로드 중...")

        try:
            vectorstore = FAISS.load_local(
                store_path,
                self.embeddings_for_search,
                allow_dangerous_deserialization=True
            )
            logger.info("벡터 스토어 로드 완료")
            return vectorstore
        except Exception as e:
            logger.error(f"벡터 스토어 로드 중 오류 발생: {e}")
            return None

    def search_similar_documents(self, query, vectorstore, k=5, filter_dict=None):
        """
        유사 문서 검색
        """
        if not vectorstore:
            logger.error("유효한 벡터 스토어가 없습니다.")
            return []
        
        logger.info(f"쿼리로 검색 중: {query}")
        
        try:
            if filter_dict:
                # 메타데이터 필터 적용한 검색
                docs = vectorstore.similarity_search(
                    query, 
                    k=k,
                    filter=filter_dict
                )
            else:
                # 기본 유사도 검색
                docs = vectorstore.similarity_search(query, k=k)
            
            return docs
        except Exception as e:
            logger.error(f"검색 중 오류 발생: {e}")
            return []

# 메인 함수
def main():
    # 경로 설정
    current_dir = os.getcwd()
    data_path = os.path.join(current_dir, "medical_data")
    vector_store_path = os.path.join(current_dir, "vector_stores")
    
    # API 키 입력 받기 (여러 개)
    api_keys_input = input("Google API 키를 입력하세요 (여러 개인 경우 쉼표로 구분): ")
    api_keys = [key.strip() for key in api_keys_input.split(',')]
    
    if not api_keys:
        logger.error("유효한 API 키가 필요합니다.")
        return
    
    # GPU 사용 가능 여부 확인
    use_gpu = torch.cuda.is_available()
    if use_gpu:
        logger.info(f"GPU 사용 가능: {torch.cuda.get_device_name(0)}")
    else:
        logger.info("GPU를 사용할 수 없습니다. CPU로 실행합니다.")

    # 벡터 스토어 객체 초기화
    vs_builder = MedicalVectorStore(
        data_path=data_path,
        vector_store_path=vector_store_path,
        use_gpu=use_gpu,
        api_keys=api_keys  # 리스트로 전달
    )
    
    
    # 의료 데이터 로드
    logger.info("의료 데이터 로드 중...")
    documents = vs_builder.load_medical_data()
    
    # 벡터 스토어 생성
    logger.info("벡터 스토어 구축 중...")
    vectorstore = vs_builder.create_vector_store(documents, batch_size=1)

    if vectorstore:
        logger.info("벡터 스토어 구축 완료!")
        
        # 간단한 검색 테스트
        test_query = "고혈압 환자의 최근 혈압 측정 기록"
        logger.info(f"테스트 쿼리 실행 중: {test_query}")
        
        results = vs_builder.search_similar_documents(test_query, vectorstore, k=3)
        logger.info(f"검색 결과: {len(results)}개 문서 찾음")
        
        # 결과 예시 출력
        for i, doc in enumerate(results):
            logger.info(f"결과 {i+1} - {doc.metadata.get('document_type')}: {doc.page_content[:150]}...")

if __name__ == "__main__":
    main()
# Out:
# 2025-05-21 22:22:35,943 - INFO - GPU를 사용할 수 없습니다. CPU로 실행합니다.
# 2025-05-21 22:22:35,944 - INFO - Using device: cpu
# 2025-05-21 22:22:36,535 - INFO - 의료 데이터 로드 중...
# 2025-05-21 22:22:36,545 - INFO - Loading 25 patients from cardiology department
# 2025-05-21 22:22:36,553 - INFO - Loading 40 patients from emergency department
# Loading files:   0%|          | 0/5 [00:00<?, ?it/s]2025-05-21 22:22:36,553 - INFO - Loading 50 patients from internal_medicine department
# 2025-05-21 22:22:36,566 - INFO - Loading 20 patients from neurology department
# 2025-05-21 22:22:36,566 - INFO - Loading 30 patients from surgery department
# Loading files: 100%|██████████| 5/5 [00:00<00:00, 136.52it/s]
# 2025-05-21 22:22:36,611 - INFO - Loaded 2210 total documents from medical data
# 2025-05-21 22:22:36,612 - INFO - 벡터 스토어 구축 중...
# 2025-05-21 22:22:36,612 - INFO - 2210개 문서로 벡터 스토어 생성 중...
# 2025-05-21 22:22:36,698 - INFO - 총 5632개의 청크 생성
# 2025-05-21 22:22:36,700 - INFO - 이전 진행 상황 발견, 인덱스 3952부터 재개합니다.
# 2025-05-21 22:22:36,700 - INFO - 기존 벡터 스토어 로드 중: c:\GitHubRepo\Medical-Artificial-Intelligence-Platform\VectorStore2\vector_stores\medical_vector_store
# 2025-05-21 22:22:36,755 - WARNING - `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.
# 2025-05-21 22:22:36,756 - INFO - 기존 벡터 스토어 로드 완료
# 2025-05-21 22:22:36,757 - INFO - 1680개의 배치로 처리 예정 (시작 인덱스: 3952)
# 배치 처리 중:   0%|          | 0/1680 [00:00<?, ?it/s]2025-05-21 22:22:36,759 - INFO - 배치 1/1680 처리 중... (인덱스 3952)
# 2025-05-21 22:22:36,759 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 1/4, 키 사용량: 1/100)
# 2025-05-21 22:22:37,799 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:22:37,882 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:22:37,890 - INFO - 배치 1 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 1/1680 [00:01<48:54,  1.75s/it]2025-05-21 22:22:38,507 - INFO - 배치 2/1680 처리 중... (인덱스 3953)
# 2025-05-21 22:22:38,508 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 2/4, 키 사용량: 2/100)
# 2025-05-21 22:22:39,348 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:22:39,382 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:22:39,383 - INFO - 배치 2 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 2/1680 [00:03<50:08,  1.79s/it]2025-05-21 22:22:40,333 - INFO - 배치 3/1680 처리 중... (인덱스 3954)
# 2025-05-21 22:22:40,333 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 3/100)
# 2025-05-21 22:22:41,182 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:22:41,216 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:22:41,218 - INFO - 배치 3 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 3/1680 [00:05<48:17,  1.73s/it]2025-05-21 22:22:41,982 - INFO - 배치 4/1680 처리 중... (인덱스 3955)
# 2025-05-21 22:22:41,983 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 4/100)
# 2025-05-21 22:22:42,819 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:22:42,853 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:22:42,854 - INFO - 배치 4 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 4/1680 [00:06<46:11,  1.65s/it]2025-05-21 22:22:43,521 - INFO - 배치 5/1680 처리 중... (인덱스 3956)
# 2025-05-21 22:22:43,522 - INFO - 분당 요청 한도에 도달했습니다. 55.2초 대기 중...
# 2025-05-21 22:23:38,761 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 5/100)
# 2025-05-21 22:23:39,761 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:23:39,847 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:23:39,848 - INFO - 배치 5 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 5/1680 [01:03<10:05:27, 21.69s/it]2025-05-21 22:23:40,733 - INFO - 배치 6/1680 처리 중... (인덱스 3957)
# 2025-05-21 22:23:40,734 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 6/100)
# 2025-05-21 22:23:41,575 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:23:41,604 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:23:41,604 - INFO - 배치 6 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 6/1680 [01:05<6:56:51, 14.94s/it] 2025-05-21 22:23:42,578 - INFO - 배치 7/1680 처리 중... (인덱스 3958)
# 2025-05-21 22:23:42,578 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 7/100)
# 2025-05-21 22:23:43,400 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:23:43,429 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:23:43,430 - INFO - 배치 7 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 7/1680 [01:07<4:53:40, 10.53s/it]2025-05-21 22:23:44,032 - INFO - 배치 8/1680 처리 중... (인덱스 3959)
# 2025-05-21 22:23:44,033 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 8/100)
# 2025-05-21 22:23:44,873 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:23:44,896 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:23:44,897 - INFO - 배치 8 벡터 스토어에 추가 완료
# 배치 처리 중:   0%|          | 8/1680 [01:08<3:32:38,  7.63s/it]2025-05-21 22:23:45,450 - INFO - 배치 9/1680 처리 중... (인덱스 3960)
# 2025-05-21 22:23:45,451 - INFO - 분당 요청 한도에 도달했습니다. 55.3초 대기 중...
# 2025-05-21 22:24:40,761 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 9/100)
# 2025-05-21 22:24:41,812 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:24:41,895 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:24:41,896 - INFO - 배치 9 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 9/1680 [02:06<10:45:47, 23.19s/it]2025-05-21 22:24:42,846 - INFO - 배치 10/1680 처리 중... (인덱스 3961)
# 2025-05-21 22:24:42,847 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 10/100)
# 2025-05-21 22:24:43,684 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:24:43,717 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:24:43,718 - INFO - 배치 10 벡터 스토어에 추가 완료
# 2025-05-21 22:24:43,772 - INFO - 벡터 스토어 저장 완료: 인덱스 3962
# 배치 처리 중:   1%|          | 10/1680 [02:07<7:41:25, 16.58s/it]2025-05-21 22:24:44,625 - INFO - 배치 11/1680 처리 중... (인덱스 3962)
# 2025-05-21 22:24:44,626 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 11/100)
# 2025-05-21 22:24:45,427 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:24:45,461 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:24:45,462 - INFO - 배치 11 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 11/1680 [02:09<5:33:47, 12.00s/it]2025-05-21 22:24:46,242 - INFO - 배치 12/1680 처리 중... (인덱스 3963)
# 2025-05-21 22:24:46,243 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 12/100)
# 2025-05-21 22:24:47,071 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:24:47,105 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:24:47,107 - INFO - 배치 12 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 12/1680 [02:10<4:03:47,  8.77s/it]2025-05-21 22:24:47,629 - INFO - 배치 13/1680 처리 중... (인덱스 3964)
# 2025-05-21 22:24:47,634 - INFO - 분당 요청 한도에 도달했습니다. 55.1초 대기 중...
# 2025-05-21 22:25:42,763 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 13/100)
# 2025-05-21 22:25:43,786 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:25:43,875 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:25:43,876 - INFO - 배치 13 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 13/1680 [03:08<10:51:26, 23.45s/it]2025-05-21 22:25:44,845 - INFO - 배치 14/1680 처리 중... (인덱스 3965)
# 2025-05-21 22:25:44,846 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 14/100)
# 2025-05-21 22:25:45,691 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:25:45,726 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:25:45,727 - INFO - 배치 14 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 14/1680 [03:09<7:49:37, 16.91s/it] 2025-05-21 22:25:46,661 - INFO - 배치 15/1680 처리 중... (인덱스 3966)
# 2025-05-21 22:25:46,662 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 15/100)
# 2025-05-21 22:25:47,500 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:25:47,535 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:25:47,537 - INFO - 배치 15 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 15/1680 [03:11<5:40:51, 12.28s/it]2025-05-21 22:25:48,214 - INFO - 배치 16/1680 처리 중... (인덱스 3967)
# 2025-05-21 22:25:48,215 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 16/100)
# 2025-05-21 22:25:49,043 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:25:49,077 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:25:49,078 - INFO - 배치 16 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 16/1680 [03:13<4:13:06,  9.13s/it]2025-05-21 22:25:50,009 - INFO - 배치 17/1680 처리 중... (인덱스 3968)
# 2025-05-21 22:25:50,010 - INFO - 분당 요청 한도에 도달했습니다. 54.8초 대기 중...
# 2025-05-21 22:26:44,764 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 17/100)
# 2025-05-21 22:26:45,803 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:26:45,894 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:26:45,895 - INFO - 배치 17 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 17/1680 [04:09<10:47:13, 23.35s/it]2025-05-21 22:26:46,442 - INFO - 배치 18/1680 처리 중... (인덱스 3969)
# 2025-05-21 22:26:46,442 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 18/100)
# 2025-05-21 22:26:47,287 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:26:47,316 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:26:47,317 - INFO - 배치 18 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 18/1680 [04:11<7:44:41, 16.78s/it] 2025-05-21 22:26:47,909 - INFO - 배치 19/1680 처리 중... (인덱스 3970)
# 2025-05-21 22:26:47,909 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 19/100)
# 2025-05-21 22:26:48,748 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:26:48,778 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:26:48,779 - INFO - 배치 19 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|          | 19/1680 [04:12<5:38:19, 12.22s/it]2025-05-21 22:26:49,522 - INFO - 배치 20/1680 처리 중... (인덱스 3971)
# 2025-05-21 22:26:49,523 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 20/100)
# 2025-05-21 22:26:50,332 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:26:50,361 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:26:50,363 - INFO - 배치 20 벡터 스토어에 추가 완료
# 2025-05-21 22:26:50,412 - INFO - 벡터 스토어 저장 완료: 인덱스 3972
# 배치 처리 중:   1%|          | 20/1680 [04:14<4:11:03,  9.07s/it]2025-05-21 22:26:51,261 - INFO - 배치 21/1680 처리 중... (인덱스 3972)
# 2025-05-21 22:26:51,262 - INFO - 분당 요청 한도에 도달했습니다. 55.5초 대기 중...
# 2025-05-21 22:27:46,765 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 21/100)
# 2025-05-21 22:27:47,648 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:27:47,689 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:27:47,690 - INFO - 배치 21 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 21/1680 [05:11<10:49:44, 23.50s/it]2025-05-21 22:27:48,390 - INFO - 배치 22/1680 처리 중... (인덱스 3973)
# 2025-05-21 22:27:48,391 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 22/100)
# 2025-05-21 22:27:49,093 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:27:49,109 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:27:49,110 - INFO - 배치 22 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 22/1680 [05:13<7:46:22, 16.88s/it] 2025-05-21 22:27:49,826 - INFO - 배치 23/1680 처리 중... (인덱스 3974)
# 2025-05-21 22:27:49,826 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 23/100)
# 2025-05-21 22:27:50,575 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:27:50,590 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:27:50,591 - INFO - 배치 23 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 23/1680 [05:14<5:40:00, 12.31s/it]2025-05-21 22:27:51,489 - INFO - 배치 24/1680 처리 중... (인덱스 3975)
# 2025-05-21 22:27:51,490 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 24/100)
# 2025-05-21 22:27:52,237 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:27:52,252 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:27:52,253 - INFO - 배치 24 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 24/1680 [05:16<4:09:27,  9.04s/it]2025-05-21 22:27:52,891 - INFO - 배치 25/1680 처리 중... (인덱스 3976)
# 2025-05-21 22:27:52,893 - INFO - 분당 요청 한도에 도달했습니다. 55.9초 대기 중...
# 2025-05-21 22:28:48,766 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 25/100)
# 2025-05-21 22:28:49,614 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:28:49,662 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:28:49,663 - INFO - 배치 25 벡터 스토어에 추가 완료
# 배치 처리 중:   1%|▏         | 25/1680 [06:13<10:51:31, 23.62s/it]2025-05-21 22:28:50,530 - INFO - 배치 26/1680 처리 중... (인덱스 3977)
# 2025-05-21 22:28:50,530 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 26/100)
# 2025-05-21 22:28:51,253 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:28:51,271 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:28:51,272 - INFO - 배치 26 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 26/1680 [06:15<7:49:25, 17.03s/it] 2025-05-21 22:28:52,179 - INFO - 배치 27/1680 처리 중... (인덱스 3978)
# 2025-05-21 22:28:52,180 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 27/100)
# 2025-05-21 22:28:52,907 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:28:52,926 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:28:52,927 - INFO - 배치 27 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 27/1680 [06:16<5:40:45, 12.37s/it]2025-05-21 22:28:53,677 - INFO - 배치 28/1680 처리 중... (인덱스 3979)
# 2025-05-21 22:28:53,677 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 28/100)
# 2025-05-21 22:28:54,379 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:28:54,396 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:28:54,396 - INFO - 배치 28 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 28/1680 [06:18<4:09:42,  9.07s/it]2025-05-21 22:28:55,048 - INFO - 배치 29/1680 처리 중... (인덱스 3980)
# 2025-05-21 22:28:55,049 - INFO - 분당 요청 한도에 도달했습니다. 55.7초 대기 중...
# 2025-05-21 22:29:50,767 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 29/100)
# 2025-05-21 22:29:51,810 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:29:51,892 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:29:51,893 - INFO - 배치 29 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 29/1680 [07:15<10:48:53, 23.58s/it]2025-05-21 22:29:52,491 - INFO - 배치 30/1680 처리 중... (인덱스 3981)
# 2025-05-21 22:29:52,491 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 30/100)
# 2025-05-21 22:29:53,311 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:29:53,340 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:29:53,342 - INFO - 배치 30 벡터 스토어에 추가 완료
# 2025-05-21 22:29:53,384 - INFO - 벡터 스토어 저장 완료: 인덱스 3982
# 배치 처리 중:   2%|▏         | 30/1680 [07:17<7:49:28, 17.07s/it] 2025-05-21 22:29:54,373 - INFO - 배치 31/1680 처리 중... (인덱스 3982)
# 2025-05-21 22:29:54,375 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 31/100)
# 2025-05-21 22:29:55,202 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:29:55,231 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:29:55,232 - INFO - 배치 31 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 31/1680 [07:19<5:43:35, 12.50s/it]2025-05-21 22:29:56,212 - INFO - 배치 32/1680 처리 중... (인덱스 3983)
# 2025-05-21 22:29:56,213 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 32/100)
# 2025-05-21 22:29:57,051 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:29:57,080 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:29:57,081 - INFO - 배치 32 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 32/1680 [07:21<4:15:42,  9.31s/it]2025-05-21 22:29:58,074 - INFO - 배치 33/1680 처리 중... (인덱스 3984)
# 2025-05-21 22:29:58,075 - INFO - 분당 요청 한도에 도달했습니다. 54.7초 대기 중...
# 2025-05-21 22:30:52,768 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 33/100)
# 2025-05-21 22:30:54,646 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:30:54,731 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:30:54,732 - INFO - 배치 33 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 33/1680 [08:18<10:51:04, 23.72s/it]2025-05-21 22:30:55,414 - INFO - 배치 34/1680 처리 중... (인덱스 3985)
# 2025-05-21 22:30:55,414 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 34/100)
# 2025-05-21 22:30:56,257 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:30:56,286 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:30:56,287 - INFO - 배치 34 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 34/1680 [08:20<7:48:51, 17.09s/it] 2025-05-21 22:30:57,039 - INFO - 배치 35/1680 처리 중... (인덱스 3986)
# 2025-05-21 22:30:57,040 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 35/100)
# 2025-05-21 22:30:57,875 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:30:57,904 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:30:57,905 - INFO - 배치 35 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 35/1680 [08:21<5:40:15, 12.41s/it]2025-05-21 22:30:58,529 - INFO - 배치 36/1680 처리 중... (인덱스 3987)
# 2025-05-21 22:30:58,530 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 36/100)
# 2025-05-21 22:30:59,341 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:30:59,369 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:30:59,370 - INFO - 배치 36 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 36/1680 [08:23<4:09:26,  9.10s/it]2025-05-21 22:30:59,917 - INFO - 배치 37/1680 처리 중... (인덱스 3988)
# 2025-05-21 22:30:59,917 - INFO - 분당 요청 한도에 도달했습니다. 54.9초 대기 중...
# 2025-05-21 22:31:54,770 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 37/100)
# 2025-05-21 22:31:55,760 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:31:55,841 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:31:55,841 - INFO - 배치 37 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 37/1680 [09:19<10:39:31, 23.35s/it]2025-05-21 22:31:56,523 - INFO - 배치 38/1680 처리 중... (인덱스 3989)
# 2025-05-21 22:31:56,524 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 38/100)
# 2025-05-21 22:31:57,318 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:31:57,343 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:31:57,345 - INFO - 배치 38 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 38/1680 [09:21<7:39:38, 16.80s/it] 2025-05-21 22:31:58,015 - INFO - 배치 39/1680 처리 중... (인덱스 3990)
# 2025-05-21 22:31:58,016 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 39/100)
# 2025-05-21 22:31:58,820 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:31:58,846 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:31:58,846 - INFO - 배치 39 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 39/1680 [09:23<5:36:06, 12.29s/it]2025-05-21 22:31:59,789 - INFO - 배치 40/1680 처리 중... (인덱스 3991)
# 2025-05-21 22:31:59,789 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 40/100)
# 2025-05-21 22:32:00,629 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:32:00,652 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:32:00,652 - INFO - 배치 40 벡터 스토어에 추가 완료
# 2025-05-21 22:32:00,721 - INFO - 벡터 스토어 저장 완료: 인덱스 3992
# 배치 처리 중:   2%|▏         | 40/1680 [09:24<4:10:31,  9.17s/it]2025-05-21 22:32:01,665 - INFO - 배치 41/1680 처리 중... (인덱스 3992)
# 2025-05-21 22:32:01,665 - INFO - 분당 요청 한도에 도달했습니다. 55.1초 대기 중...
# 2025-05-21 22:32:56,773 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 41/100)
# 2025-05-21 22:32:57,609 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:32:57,645 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:32:57,646 - INFO - 배치 41 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▏         | 41/1680 [10:21<10:41:53, 23.50s/it]2025-05-21 22:32:58,606 - INFO - 배치 42/1680 처리 중... (인덱스 3993)
# 2025-05-21 22:32:58,606 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 42/100)
# 2025-05-21 22:32:59,331 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:32:59,340 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:32:59,340 - INFO - 배치 42 벡터 스토어에 추가 완료
# 배치 처리 중:   2%|▎         | 42/1680 [10:23<7:43:07, 16.96s/it] 2025-05-21 22:33:00,325 - INFO - 배치 43/1680 처리 중... (인덱스 3994)
# 2025-05-21 22:33:00,325 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 43/100)
# 2025-05-21 22:33:01,049 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:33:01,064 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:33:01,065 - INFO - 배치 43 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 43/1680 [10:25<5:35:49, 12.31s/it]2025-05-21 22:33:01,770 - INFO - 배치 44/1680 처리 중... (인덱스 3995)
# 2025-05-21 22:33:01,770 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 44/100)
# 2025-05-21 22:33:02,475 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:33:02,490 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:33:02,491 - INFO - 배치 44 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 44/1680 [10:26<4:08:38,  9.12s/it]2025-05-21 22:33:03,447 - INFO - 배치 45/1680 처리 중... (인덱스 3996)
# 2025-05-21 22:33:03,447 - INFO - 분당 요청 한도에 도달했습니다. 55.3초 대기 중...
# 2025-05-21 22:33:58,774 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 45/100)
# 2025-05-21 22:33:59,733 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:33:59,778 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:33:59,779 - INFO - 배치 45 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 45/1680 [11:23<10:39:20, 23.46s/it]2025-05-21 22:34:00,375 - INFO - 배치 46/1680 처리 중... (인덱스 3997)
# 2025-05-21 22:34:00,376 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 46/100)
# 2025-05-21 22:34:01,097 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:34:01,114 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:34:01,115 - INFO - 배치 46 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 46/1680 [11:25<7:40:55, 16.92s/it] 2025-05-21 22:34:02,048 - INFO - 배치 47/1680 처리 중... (인덱스 3998)
# 2025-05-21 22:34:02,048 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 47/100)
# 2025-05-21 22:34:02,765 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:34:02,783 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:34:02,783 - INFO - 배치 47 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 47/1680 [11:26<5:36:03, 12.35s/it]2025-05-21 22:34:03,713 - INFO - 배치 48/1680 처리 중... (인덱스 3999)
# 2025-05-21 22:34:03,714 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 48/100)
# 2025-05-21 22:34:04,408 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:34:04,422 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:34:04,428 - INFO - 배치 48 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 48/1680 [11:28<4:07:07,  9.09s/it]2025-05-21 22:34:05,190 - INFO - 배치 49/1680 처리 중... (인덱스 4000)
# 2025-05-21 22:34:05,190 - INFO - 분당 요청 한도에 도달했습니다. 55.6초 대기 중...
# 2025-05-21 22:35:00,776 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 49/100)
# 2025-05-21 22:35:02,275 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:35:02,320 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:35:02,322 - INFO - 배치 49 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 49/1680 [12:26<10:46:41, 23.79s/it]2025-05-21 22:35:03,291 - INFO - 배치 50/1680 처리 중... (인덱스 4001)
# 2025-05-21 22:35:03,291 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 50/100)
# 2025-05-21 22:35:03,988 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:35:04,006 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:35:04,006 - INFO - 배치 50 벡터 스토어에 추가 완료
# 2025-05-21 22:35:04,058 - INFO - 벡터 스토어 저장 완료: 인덱스 4002
# 배치 처리 중:   3%|▎         | 50/1680 [12:27<7:43:07, 17.05s/it] 2025-05-21 22:35:04,606 - INFO - 배치 51/1680 처리 중... (인덱스 4002)
# 2025-05-21 22:35:04,606 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 51/100)
# 2025-05-21 22:35:05,318 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:35:05,334 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:35:05,335 - INFO - 배치 51 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 51/1680 [12:29<5:36:59, 12.41s/it]2025-05-21 22:35:06,202 - INFO - 배치 52/1680 처리 중... (인덱스 4003)
# 2025-05-21 22:35:06,203 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 52/100)
# 2025-05-21 22:35:06,901 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:35:06,918 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:35:06,919 - INFO - 배치 52 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 52/1680 [12:31<4:09:01,  9.18s/it]2025-05-21 22:35:07,831 - INFO - 배치 53/1680 처리 중... (인덱스 4004)
# 2025-05-21 22:35:07,832 - INFO - 분당 요청 한도에 도달했습니다. 54.9초 대기 중...
# 2025-05-21 22:36:02,777 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 53/100)
# 2025-05-21 22:36:03,580 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:36:03,617 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:36:03,618 - INFO - 배치 53 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 53/1680 [13:27<10:33:15, 23.35s/it]2025-05-21 22:36:04,260 - INFO - 배치 54/1680 처리 중... (인덱스 4005)
# 2025-05-21 22:36:04,262 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 54/100)
# 2025-05-21 22:36:04,948 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:36:04,964 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:36:04,965 - INFO - 배치 54 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 54/1680 [13:28<7:33:33, 16.74s/it] 2025-05-21 22:36:05,560 - INFO - 배치 55/1680 처리 중... (인덱스 4006)
# 2025-05-21 22:36:05,560 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 55/100)
# 2025-05-21 22:36:06,260 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:36:06,275 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:36:06,276 - INFO - 배치 55 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 55/1680 [13:30<5:31:10, 12.23s/it]2025-05-21 22:36:07,266 - INFO - 배치 56/1680 처리 중... (인덱스 4007)
# 2025-05-21 22:36:07,267 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 56/100)
# 2025-05-21 22:36:07,967 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:36:07,982 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:36:07,983 - INFO - 배치 56 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 56/1680 [13:31<4:02:25,  8.96s/it]2025-05-21 22:36:08,590 - INFO - 배치 57/1680 처리 중... (인덱스 4008)
# 2025-05-21 22:36:08,591 - INFO - 분당 요청 한도에 도달했습니다. 56.2초 대기 중...
# 2025-05-21 22:37:04,778 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 57/100)
# 2025-05-21 22:37:06,260 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:37:06,301 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:37:06,302 - INFO - 배치 57 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 57/1680 [14:30<10:45:55, 23.88s/it]2025-05-21 22:37:07,287 - INFO - 배치 58/1680 처리 중... (인덱스 4009)
# 2025-05-21 22:37:07,288 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 2/4, 키 사용량: 58/100)
# 2025-05-21 22:37:08,003 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:37:08,019 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:37:08,021 - INFO - 배치 58 벡터 스토어에 추가 완료
# 배치 처리 중:   3%|▎         | 58/1680 [14:32<7:44:17, 17.17s/it] 2025-05-21 22:37:08,818 - INFO - 배치 59/1680 처리 중... (인덱스 4010)
# 2025-05-21 22:37:08,819 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 59/100)
# 2025-05-21 22:37:09,510 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:37:09,524 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:37:09,525 - INFO - 배치 59 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▎         | 59/1680 [14:33<5:38:21, 12.52s/it]2025-05-21 22:37:10,493 - INFO - 배치 60/1680 처리 중... (인덱스 4011)
# 2025-05-21 22:37:10,493 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 60/100)
# 2025-05-21 22:37:11,215 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:37:11,231 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:37:11,232 - INFO - 배치 60 벡터 스토어에 추가 완료
# 2025-05-21 22:37:11,280 - INFO - 벡터 스토어 저장 완료: 인덱스 4012
# 배치 처리 중:   4%|▎         | 60/1680 [14:35<4:09:36,  9.25s/it]2025-05-21 22:37:12,085 - INFO - 배치 61/1680 처리 중... (인덱스 4012)
# 2025-05-21 22:37:12,086 - INFO - 분당 요청 한도에 도달했습니다. 54.7초 대기 중...
# 2025-05-21 22:38:06,779 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 61/100)
# 2025-05-21 22:38:08,294 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:38:08,342 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:38:08,342 - INFO - 배치 61 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▎         | 61/1680 [15:32<10:36:39, 23.59s/it]2025-05-21 22:38:09,162 - INFO - 배치 62/1680 처리 중... (인덱스 4013)
# 2025-05-21 22:38:09,163 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 62/100)
# 2025-05-21 22:38:09,865 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:38:09,883 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:38:09,883 - INFO - 배치 62 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▎         | 62/1680 [15:33<7:36:11, 16.92s/it] 2025-05-21 22:38:10,499 - INFO - 배치 63/1680 처리 중... (인덱스 4014)
# 2025-05-21 22:38:10,499 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 63/100)
# 2025-05-21 22:38:11,201 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:38:11,219 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:38:11,220 - INFO - 배치 63 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▍         | 63/1680 [15:35<5:31:37, 12.30s/it]2025-05-21 22:38:12,042 - INFO - 배치 64/1680 처리 중... (인덱스 4015)
# 2025-05-21 22:38:12,042 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 64/100)
# 2025-05-21 22:38:12,777 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:38:12,795 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:38:12,796 - INFO - 배치 64 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▍         | 64/1680 [15:37<4:06:03,  9.14s/it]2025-05-21 22:38:13,783 - INFO - 배치 65/1680 처리 중... (인덱스 4016)
# 2025-05-21 22:38:13,784 - INFO - 분당 요청 한도에 도달했습니다. 55.0초 대기 중...
# 2025-05-21 22:39:08,780 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 65/100)
# 2025-05-21 22:39:09,804 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:39:09,850 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:39:09,851 - INFO - 배치 65 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▍         | 65/1680 [16:33<10:31:48, 23.47s/it]2025-05-21 22:39:10,708 - INFO - 배치 66/1680 처리 중... (인덱스 4017)
# 2025-05-21 22:39:10,709 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 66/100)
# 2025-05-21 22:39:11,432 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:39:11,449 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:39:11,449 - INFO - 배치 66 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▍         | 66/1680 [16:35<7:35:42, 16.94s/it] 2025-05-21 22:39:12,409 - INFO - 배치 67/1680 처리 중... (인덱스 4018)
# 2025-05-21 22:39:12,410 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 67/100)
# 2025-05-21 22:39:13,126 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:39:13,144 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:39:13,145 - INFO - 배치 67 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▍         | 67/1680 [16:37<5:30:34, 12.30s/it]2025-05-21 22:39:13,869 - INFO - 배치 68/1680 처리 중... (인덱스 4019)
# 2025-05-21 22:39:13,869 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 68/100)
# 2025-05-21 22:39:14,583 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:39:14,601 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:39:14,602 - INFO - 배치 68 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▍         | 68/1680 [16:38<4:01:47,  9.00s/it]2025-05-21 22:39:15,176 - INFO - 배치 69/1680 처리 중... (인덱스 4020)
# 2025-05-21 22:39:15,177 - INFO - 분당 요청 한도에 도달했습니다. 55.6초 대기 중...
# 2025-05-21 22:40:10,781 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 69/100)
# 2025-05-21 22:40:11,598 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:40:11,639 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:40:11,640 - INFO - 배치 69 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▍         | 69/1680 [17:35<10:30:42, 23.49s/it]2025-05-21 22:40:12,475 - INFO - 배치 70/1680 처리 중... (인덱스 4021)
# 2025-05-21 22:40:12,476 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 70/100)
# 2025-05-21 22:40:13,190 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:40:13,208 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:40:13,210 - INFO - 배치 70 벡터 스토어에 추가 완료
# 2025-05-21 22:40:13,266 - INFO - 벡터 스토어 저장 완료: 인덱스 4022
# 배치 처리 중:   4%|▍         | 70/1680 [17:37<7:34:51, 16.95s/it] 2025-05-21 22:40:14,171 - INFO - 배치 71/1680 처리 중... (인덱스 4022)
# 2025-05-21 22:40:14,172 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 71/100)
# 2025-05-21 22:40:14,869 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:40:14,886 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:40:14,887 - INFO - 배치 71 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▍         | 71/1680 [17:38<5:28:01, 12.23s/it]2025-05-21 22:40:15,391 - INFO - 배치 72/1680 처리 중... (인덱스 4023)
# 2025-05-21 22:40:15,392 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 72/100)
# 2025-05-21 22:40:16,108 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:40:16,124 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:40:16,125 - INFO - 배치 72 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▍         | 72/1680 [17:39<3:59:54,  8.95s/it]2025-05-21 22:40:16,688 - INFO - 배치 73/1680 처리 중... (인덱스 4024)
# 2025-05-21 22:40:16,689 - INFO - 분당 요청 한도에 도달했습니다. 56.1초 대기 중...
# 2025-05-21 22:41:12,782 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 73/100)
# 2025-05-21 22:41:13,646 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:41:13,695 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:41:13,697 - INFO - 배치 73 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▍         | 73/1680 [18:37<10:33:40, 23.66s/it]2025-05-21 22:41:14,667 - INFO - 배치 74/1680 처리 중... (인덱스 4025)
# 2025-05-21 22:41:14,667 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 74/100)
# 2025-05-21 22:41:15,359 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:41:15,374 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:41:15,375 - INFO - 배치 74 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▍         | 74/1680 [18:39<7:34:48, 16.99s/it] 2025-05-21 22:41:16,099 - INFO - 배치 75/1680 처리 중... (인덱스 4026)
# 2025-05-21 22:41:16,100 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 75/100)
# 2025-05-21 22:41:16,809 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:41:16,824 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:41:16,824 - INFO - 배치 75 벡터 스토어에 추가 완료
# 배치 처리 중:   4%|▍         | 75/1680 [18:40<5:30:25, 12.35s/it]2025-05-21 22:41:17,626 - INFO - 배치 76/1680 처리 중... (인덱스 4027)
# 2025-05-21 22:41:17,626 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 76/100)
# 2025-05-21 22:41:18,352 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:41:18,369 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:41:18,370 - INFO - 배치 76 벡터 스토어에 추가 완료
# 배치 처리 중:   5%|▍         | 76/1680 [18:42<4:01:44,  9.04s/it]2025-05-21 22:41:18,946 - INFO - 배치 77/1680 처리 중... (인덱스 4028)
# 2025-05-21 22:41:18,947 - INFO - 분당 요청 한도에 도달했습니다. 55.8초 대기 중...
# 2025-05-21 22:42:14,783 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 77/100)
# 2025-05-21 22:42:16,297 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:42:16,345 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:42:16,346 - INFO - 배치 77 벡터 스토어에 추가 완료
# 배치 처리 중:   5%|▍         | 77/1680 [19:40<10:37:02, 23.84s/it]2025-05-21 22:42:17,329 - INFO - 배치 78/1680 처리 중... (인덱스 4029)
# 2025-05-21 22:42:17,330 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 78/100)
# 2025-05-21 22:42:18,033 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:42:18,050 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:42:18,051 - INFO - 배치 78 벡터 스토어에 추가 완료
# 배치 처리 중:   5%|▍         | 78/1680 [19:42<7:38:12, 17.16s/it] 2025-05-21 22:42:18,895 - INFO - 배치 79/1680 처리 중... (인덱스 4030)
# 2025-05-21 22:42:18,896 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 79/100)
# 2025-05-21 22:42:19,593 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:42:19,610 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:42:19,611 - INFO - 배치 79 벡터 스토어에 추가 완료
# 배치 처리 중:   5%|▍         | 79/1680 [19:43<5:32:05, 12.45s/it]2025-05-21 22:42:20,337 - INFO - 배치 80/1680 처리 중... (인덱스 4031)
# 2025-05-21 22:42:20,337 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 80/100)
# 2025-05-21 22:42:21,067 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:42:21,084 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:42:21,085 - INFO - 배치 80 벡터 스토어에 추가 완료
# 2025-05-21 22:42:21,134 - INFO - 벡터 스토어 저장 완료: 인덱스 4032
# 배치 처리 중:   5%|▍         | 80/1680 [19:45<4:05:08,  9.19s/it]2025-05-21 22:42:21,941 - INFO - 배치 81/1680 처리 중... (인덱스 4032)
# 2025-05-21 22:42:21,942 - INFO - 분당 요청 한도에 도달했습니다. 54.8초 대기 중...
# 2025-05-21 22:43:16,784 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 81/100)
# 2025-05-21 22:43:17,623 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:43:17,669 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:43:17,670 - INFO - 배치 81 벡터 스토어에 추가 완료
# 배치 처리 중:   5%|▍         | 81/1680 [20:41<10:22:55, 23.37s/it]2025-05-21 22:43:18,405 - INFO - 배치 82/1680 처리 중... (인덱스 4033)
# 2025-05-21 22:43:18,405 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 82/100)
# 2025-05-21 22:43:19,103 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:43:19,120 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:43:19,121 - INFO - 배치 82 벡터 스토어에 추가 완료
# 배치 처리 중:   5%|▍         | 82/1680 [20:43<7:27:00, 16.78s/it] 2025-05-21 22:43:19,811 - INFO - 배치 83/1680 처리 중... (인덱스 4034)
# 2025-05-21 22:43:19,811 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 83/100)
# 2025-05-21 22:43:20,505 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:43:20,521 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:43:20,522 - INFO - 배치 83 벡터 스토어에 추가 완료
# 배치 처리 중:   5%|▍         | 83/1680 [20:44<5:25:55, 12.24s/it]2025-05-21 22:43:21,465 - INFO - 배치 84/1680 처리 중... (인덱스 4035)
# 2025-05-21 22:43:21,466 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 84/100)
# 2025-05-21 22:43:22,176 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:43:22,193 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:43:22,194 - INFO - 배치 84 벡터 스토어에 추가 완료
# 배치 처리 중:   5%|▌         | 84/1680 [20:46<3:59:58,  9.02s/it]2025-05-21 22:43:22,966 - INFO - 배치 85/1680 처리 중... (인덱스 4036)
# 2025-05-21 22:43:22,966 - INFO - 분당 요청 한도에 도달했습니다. 55.8초 대기 중...
# 2025-05-21 22:44:18,786 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 85/100)
# 2025-05-21 22:44:19,699 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:44:19,741 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:44:19,742 - INFO - 배치 85 벡터 스토어에 추가 완료
# 배치 처리 중:   5%|▌         | 85/1680 [21:43<10:27:42, 23.61s/it]2025-05-21 22:44:20,626 - INFO - 배치 86/1680 처리 중... (인덱스 4037)
# 2025-05-21 22:44:20,626 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 86/100)
# 2025-05-21 22:44:21,335 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:44:21,350 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:44:21,352 - INFO - 배치 86 벡터 스토어에 추가 완료
# 배치 처리 중:   5%|▌         | 86/1680 [21:45<7:31:06, 16.98s/it] 2025-05-21 22:44:22,130 - INFO - 배치 87/1680 처리 중... (인덱스 4038)
# 2025-05-21 22:44:22,130 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 87/100)
# 2025-05-21 22:44:22,827 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:44:22,842 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:44:22,843 - INFO - 배치 87 벡터 스토어에 추가 완료
# 배치 처리 중:   5%|▌         | 87/1680 [21:46<5:26:45, 12.31s/it]2025-05-21 22:44:23,534 - INFO - 배치 88/1680 처리 중... (인덱스 4039)
# 2025-05-21 22:44:23,535 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 88/100)
# 2025-05-21 22:44:24,249 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:44:24,265 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:44:24,266 - INFO - 배치 88 벡터 스토어에 추가 완료
# 배치 처리 중:   5%|▌         | 88/1680 [21:48<3:58:45,  9.00s/it]2025-05-21 22:44:24,811 - INFO - 배치 89/1680 처리 중... (인덱스 4040)
# 2025-05-21 22:44:24,811 - INFO - 분당 요청 한도에 도달했습니다. 56.0초 대기 중...
# 2025-05-21 22:45:20,788 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 89/100)
# 2025-05-21 22:45:22,291 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:45:22,338 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:45:22,339 - INFO - 배치 89 벡터 스토어에 추가 완료
# 배치 처리 중:   5%|▌         | 89/1680 [22:46<10:31:41, 23.82s/it]2025-05-21 22:45:23,223 - INFO - 배치 90/1680 처리 중... (인덱스 4041)
# 2025-05-21 22:45:23,224 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 90/100)
# 2025-05-21 22:45:23,929 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:45:23,947 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:45:23,948 - INFO - 배치 90 벡터 스토어에 추가 완료
# 2025-05-21 22:45:23,997 - INFO - 벡터 스토어 저장 완료: 인덱스 4042
# 배치 처리 중:   5%|▌         | 90/1680 [22:47<7:33:42, 17.12s/it] 2025-05-21 22:45:24,707 - INFO - 배치 91/1680 처리 중... (인덱스 4042)
# 2025-05-21 22:45:24,708 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 91/100)
# 2025-05-21 22:45:25,426 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:45:25,444 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:45:25,445 - INFO - 배치 91 벡터 스토어에 추가 완료
# 배치 처리 중:   5%|▌         | 91/1680 [22:49<5:30:06, 12.46s/it]2025-05-21 22:45:26,307 - INFO - 배치 92/1680 처리 중... (인덱스 4043)
# 2025-05-21 22:45:26,307 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 92/100)
# 2025-05-21 22:45:27,005 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-21 22:45:27,023 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-21 22:45:27,025 - INFO - 배치 92 벡터 스토어에 추가 완료
# ...
# 2025-05-22 00:20:48,587 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 91/100)
# 2025-05-22 00:20:49,408 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:20:49,441 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:20:49,443 - INFO - 배치 466 벡터 스토어에 추가 완료
# 배치 처리 중:  28%|██▊       | 466/1680 [1:58:13<4:08:12, 12.27s/it]2025-05-22 00:20:50,160 - INFO - 배치 467/1680 처리 중... (인덱스 4418)
# 2025-05-22 00:20:50,161 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 92/100)
# 2025-05-22 00:20:50,956 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:20:50,993 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:20:50,994 - INFO - 배치 467 벡터 스토어에 추가 완료
# 배치 처리 중:  28%|██▊       | 467/1680 [1:58:14<3:02:36,  9.03s/it]2025-05-22 00:20:51,645 - INFO - 배치 468/1680 처리 중... (인덱스 4419)
# 2025-05-22 00:20:51,645 - INFO - 분당 요청 한도에 도달했습니다. 55.0초 대기 중...
# 2025-05-22 00:21:46,660 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 93/100)
# 2025-05-22 00:21:47,989 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 429 Too Many Requests"
# 2025-05-22 00:21:47,991 - WARNING - API 키 한도 초과 오류: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# 2025-05-22 00:21:47,991 - WARNING - API 키 [AIzaSyAW...] 소진됨 (100회 사용). 다음 키로 전환 시도...
# 2025-05-22 00:21:48,425 - INFO - 새 API 키 [AIzaSyDw...](으)로 전환 성공!
# 2025-05-22 00:21:48,426 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 1/4, 키 사용량: 1/100)
# 2025-05-22 00:21:50,275 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:21:50,361 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:21:50,363 - INFO - 배치 468 벡터 스토어에 추가 완료
# 배치 처리 중:  28%|██▊       | 468/1680 [1:59:14<8:09:28, 24.23s/it]2025-05-22 00:21:51,342 - INFO - 배치 469/1680 처리 중... (인덱스 4420)
# 2025-05-22 00:21:51,342 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 2/4, 키 사용량: 2/100)
# 2025-05-22 00:21:52,184 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:21:52,218 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:21:52,220 - INFO - 배치 469 벡터 스토어에 추가 완료
# 배치 처리 중:  28%|██▊       | 469/1680 [1:59:16<5:51:14, 17.40s/it]2025-05-22 00:21:52,809 - INFO - 배치 470/1680 처리 중... (인덱스 4421)
# 2025-05-22 00:21:52,810 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 3/100)
# 2025-05-22 00:21:53,649 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:21:53,681 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:21:53,683 - INFO - 배치 470 벡터 스토어에 추가 완료
# 2025-05-22 00:21:53,750 - INFO - 벡터 스토어 저장 완료: 인덱스 4422
# 배치 처리 중:  28%|██▊       | 470/1680 [1:59:17<4:16:43, 12.73s/it]2025-05-22 00:21:54,638 - INFO - 배치 471/1680 처리 중... (인덱스 4422)
# 2025-05-22 00:21:54,638 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 4/100)
# 2025-05-22 00:21:55,466 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:21:55,501 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:21:55,503 - INFO - 배치 471 벡터 스토어에 추가 완료
# 배치 처리 중:  28%|██▊       | 471/1680 [1:59:19<3:08:06,  9.34s/it]2025-05-22 00:21:56,053 - INFO - 배치 472/1680 처리 중... (인덱스 4423)
# 2025-05-22 00:21:56,053 - INFO - 분당 요청 한도에 도달했습니다. 54.4초 대기 중...
# 2025-05-22 00:22:50,428 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 5/100)
# 2025-05-22 00:22:51,275 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:22:51,317 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:22:51,320 - INFO - 배치 472 벡터 스토어에 추가 완료
# 배치 처리 중:  28%|██▊       | 472/1680 [2:00:15<7:51:10, 23.40s/it]2025-05-22 00:22:52,280 - INFO - 배치 473/1680 처리 중... (인덱스 4424)
# 2025-05-22 00:22:52,281 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 6/100)
# 2025-05-22 00:22:52,991 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:22:53,006 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:22:53,007 - INFO - 배치 473 벡터 스토어에 추가 완료
# 배치 처리 중:  28%|██▊       | 473/1680 [2:00:17<5:39:09, 16.86s/it]2025-05-22 00:22:53,871 - INFO - 배치 474/1680 처리 중... (인덱스 4425)
# 2025-05-22 00:22:53,872 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 7/100)
# 2025-05-22 00:22:54,590 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:22:54,606 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:22:54,608 - INFO - 배치 474 벡터 스토어에 추가 완료
# 배치 처리 중:  28%|██▊       | 474/1680 [2:00:18<4:06:43, 12.28s/it]2025-05-22 00:22:55,449 - INFO - 배치 475/1680 처리 중... (인덱스 4426)
# 2025-05-22 00:22:55,449 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 8/100)
# 2025-05-22 00:22:56,177 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:22:56,193 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:22:56,195 - INFO - 배치 475 벡터 스토어에 추가 완료
# 배치 처리 중:  28%|██▊       | 475/1680 [2:00:20<3:00:48,  9.00s/it]2025-05-22 00:22:56,818 - INFO - 배치 476/1680 처리 중... (인덱스 4427)
# 2025-05-22 00:22:56,818 - INFO - 분당 요청 한도에 도달했습니다. 55.6초 대기 중...
# 2025-05-22 00:23:52,430 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 9/100)
# 2025-05-22 00:23:53,278 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:23:53,325 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:23:53,327 - INFO - 배치 476 벡터 스토어에 추가 완료
# 배치 처리 중:  28%|██▊       | 476/1680 [2:01:17<7:51:32, 23.50s/it]2025-05-22 00:23:54,139 - INFO - 배치 477/1680 처리 중... (인덱스 4428)
# 2025-05-22 00:23:54,140 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 10/100)
# 2025-05-22 00:23:55,520 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:23:55,537 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:23:55,538 - INFO - 배치 477 벡터 스토어에 추가 완료
# 배치 처리 중:  28%|██▊       | 477/1680 [2:01:19<5:43:55, 17.15s/it]2025-05-22 00:23:56,488 - INFO - 배치 478/1680 처리 중... (인덱스 4429)
# 2025-05-22 00:23:56,489 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 11/100)
# 2025-05-22 00:23:57,189 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:23:57,206 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:23:57,207 - INFO - 배치 478 벡터 스토어에 추가 완료
# 배치 처리 중:  28%|██▊       | 478/1680 [2:01:21<4:09:23, 12.45s/it]2025-05-22 00:23:57,959 - INFO - 배치 479/1680 처리 중... (인덱스 4430)
# 2025-05-22 00:23:57,961 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 12/100)
# 2025-05-22 00:23:58,670 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:23:58,687 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:23:58,689 - INFO - 배치 479 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▊       | 479/1680 [2:01:22<3:02:07,  9.10s/it]2025-05-22 00:23:59,242 - INFO - 배치 480/1680 처리 중... (인덱스 4431)
# 2025-05-22 00:23:59,243 - INFO - 분당 요청 한도에 도달했습니다. 55.2초 대기 중...
# 2025-05-22 00:24:54,431 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 13/100)
# 2025-05-22 00:24:55,255 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:24:55,297 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:24:55,299 - INFO - 배치 480 벡터 스토어에 추가 완료
# 2025-05-22 00:24:55,404 - INFO - 벡터 스토어 저장 완료: 인덱스 4432
# 배치 처리 중:  29%|██▊       | 480/1680 [2:02:19<7:49:06, 23.46s/it]2025-05-22 00:24:56,196 - INFO - 배치 481/1680 처리 중... (인덱스 4432)
# 2025-05-22 00:24:56,197 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 14/100)
# 2025-05-22 00:24:56,927 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:24:56,942 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:24:56,943 - INFO - 배치 481 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▊       | 481/1680 [2:02:20<5:35:48, 16.80s/it]2025-05-22 00:24:57,480 - INFO - 배치 482/1680 처리 중... (인덱스 4433)
# 2025-05-22 00:24:57,480 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 15/100)
# 2025-05-22 00:24:58,200 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:24:58,216 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:24:58,217 - INFO - 배치 482 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▊       | 482/1680 [2:02:22<4:04:18, 12.24s/it]2025-05-22 00:24:59,057 - INFO - 배치 483/1680 처리 중... (인덱스 4434)
# 2025-05-22 00:24:59,058 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 16/100)
# 2025-05-22 00:24:59,758 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:24:59,772 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:24:59,774 - INFO - 배치 483 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▉       | 483/1680 [2:02:23<2:58:21,  8.94s/it]2025-05-22 00:25:00,308 - INFO - 배치 484/1680 처리 중... (인덱스 4435)
# 2025-05-22 00:25:00,308 - INFO - 분당 요청 한도에 도달했습니다. 56.1초 대기 중...
# 2025-05-22 00:25:56,432 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 17/100)
# 2025-05-22 00:25:57,298 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:25:57,345 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:25:57,346 - INFO - 배치 484 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▉       | 484/1680 [2:03:21<7:50:33, 23.61s/it]2025-05-22 00:25:58,135 - INFO - 배치 485/1680 처리 중... (인덱스 4436)
# 2025-05-22 00:25:58,135 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 18/100)
# 2025-05-22 00:25:58,857 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:25:58,875 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:25:58,876 - INFO - 배치 485 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▉       | 485/1680 [2:03:22<5:38:38, 17.00s/it]2025-05-22 00:25:59,728 - INFO - 배치 486/1680 처리 중... (인덱스 4437)
# 2025-05-22 00:25:59,729 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 19/100)
# 2025-05-22 00:26:00,445 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:26:00,463 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:26:00,465 - INFO - 배치 486 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▉       | 486/1680 [2:03:24<4:05:10, 12.32s/it]2025-05-22 00:26:01,124 - INFO - 배치 487/1680 처리 중... (인덱스 4438)
# 2025-05-22 00:26:01,124 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 20/100)
# 2025-05-22 00:26:01,853 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:26:01,871 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:26:01,873 - INFO - 배치 487 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▉       | 487/1680 [2:03:25<3:00:12,  9.06s/it]2025-05-22 00:26:02,586 - INFO - 배치 488/1680 처리 중... (인덱스 4439)
# 2025-05-22 00:26:02,587 - INFO - 분당 요청 한도에 도달했습니다. 55.8초 대기 중...
# 2025-05-22 00:26:58,432 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 21/100)
# 2025-05-22 00:26:59,311 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:26:59,356 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:26:59,357 - INFO - 배치 488 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▉       | 488/1680 [2:04:23<7:49:00, 23.61s/it]2025-05-22 00:27:00,132 - INFO - 배치 489/1680 처리 중... (인덱스 4440)
# 2025-05-22 00:27:00,133 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 22/100)
# 2025-05-22 00:27:00,864 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:27:00,880 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:27:00,882 - INFO - 배치 489 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▉       | 489/1680 [2:04:24<5:35:54, 16.92s/it]2025-05-22 00:27:01,455 - INFO - 배치 490/1680 처리 중... (인덱스 4441)
# 2025-05-22 00:27:01,455 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 23/100)
# 2025-05-22 00:27:02,188 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:27:02,205 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:27:02,206 - INFO - 배치 490 벡터 스토어에 추가 완료
# 2025-05-22 00:27:02,264 - INFO - 벡터 스토어 저장 완료: 인덱스 4442
# 배치 처리 중:  29%|██▉       | 490/1680 [2:04:26<4:02:46, 12.24s/it]2025-05-22 00:27:02,772 - INFO - 배치 491/1680 처리 중... (인덱스 4442)
# 2025-05-22 00:27:02,772 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 24/100)
# 2025-05-22 00:27:03,489 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:27:03,507 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:27:03,508 - INFO - 배치 491 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▉       | 491/1680 [2:04:27<2:58:29,  9.01s/it]2025-05-22 00:27:04,234 - INFO - 배치 492/1680 처리 중... (인덱스 4443)
# 2025-05-22 00:27:04,234 - INFO - 분당 요청 한도에 도달했습니다. 56.2초 대기 중...
# 2025-05-22 00:28:00,434 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 25/100)
# 2025-05-22 00:28:01,355 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:28:01,401 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:28:01,402 - INFO - 배치 492 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▉       | 492/1680 [2:05:25<7:49:52, 23.73s/it]2025-05-22 00:28:02,321 - INFO - 배치 493/1680 처리 중... (인덱스 4444)
# 2025-05-22 00:28:02,321 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 26/100)
# 2025-05-22 00:28:03,033 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:28:03,050 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:28:03,052 - INFO - 배치 493 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▉       | 493/1680 [2:05:27<5:37:18, 17.05s/it]2025-05-22 00:28:03,784 - INFO - 배치 494/1680 처리 중... (인덱스 4445)
# 2025-05-22 00:28:03,784 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 3/4, 키 사용량: 27/100)
# 2025-05-22 00:28:04,492 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:28:04,510 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:28:04,510 - INFO - 배치 494 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▉       | 494/1680 [2:05:28<4:04:47, 12.38s/it]2025-05-22 00:28:05,280 - INFO - 배치 495/1680 처리 중... (인덱스 4446)
# 2025-05-22 00:28:05,281 - INFO - 임베딩 API 호출 (배치 크기: 1, 분당 요청: 4/4, 키 사용량: 28/100)
# 2025-05-22 00:28:06,012 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-exp-03-07:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-05-22 00:28:06,029 - INFO - 임베딩 결과: 길이=1, 차원=3072
# 2025-05-22 00:28:06,030 - INFO - 배치 495 벡터 스토어에 추가 완료
# 배치 처리 중:  29%|██▉       | 495/1680 [2:05:30<3:00:35,  9.14s/it]2025-05-22 00:28:06,862 - INFO - 배치 496/1680 처리 중... (인덱스 4447)
# 2025-05-22 00:28:06,862 - INFO - 분당 요청 한도에 도달했습니다. 55.6초 대기 중...

# %% [markdown]
# AIzaSyDgoKVgiZTgfU4tWn36kj7EXLBMuxaMscQ,AIzaSyBBxCsZCpYHtDQr9DjAldp_CElT5Gjn-aQ,AIzaSyDVFsuU6213Vt2QUqSJabZXfx_0ZH-bqB0,AIzaSyA9Vqa3pudBOJt5ceoEsaCxYYENa11vltc,AIzaSyAIMv1uNZTgdbZ5taAQ_BjGCb9uQzjYz1g,AIzaSyCndJCfaKSc0hU7FjNocNPTJT7bH1R1gvc,AIzaSyCoFHBvN-MOQoW3hAXWlpstddRWkOhVw_c

# %% [markdown]
# AIzaSyAxhAWEGmK9lUkZHi03-5VPRiEondTKUCk,AIzaSyCpi0aoxPFWU8g6W19SnAx_AOTvFVH_NXk,AIzaSyC2vq8XJgw-W9KxX4D6-8RjKcN9SdhstYw,AIzaSyAwCQdrHFWuGoYeE7o8mlOv8mlNdDY9Lqk,AIzaSyCEnPLLK6hM7-Hesht9xtiTcPmrnjnLkBU,AIzaSyDY47yj8ueOFUJZjlh-0FlTKMJnPJMMd24,AIzaSyBObSDpud8lGlcwPBpBR9tepY3htarR3Vs,AIzaSyB5c0ouMtjTitVHnfJUYZw8XtTpSH2hiBs,AIzaSyD-P6K7c2WbQdPt787KzsysBialkKHEsck,AIzaSyDZRk1If1DpNih6_Z9zN0xVNoS3zon87cM,AIzaSyCugPmVpRa8d73W8349ftjqMsJWaIj6NHM

# %% [markdown]
# AIzaSyCX5X19glBVjEMjfzKmVQUXz7vha2eHvt4,AIzaSyD8khCNEFicOQcO5AcKMQZrWww2G40TYQY,AIzaSyCvBnxbKYFdi-Jt98EuN_SyLAcBt0Lju6U,AIzaSyDUKEF_qXj6H0e8JckAGa6-3oOEu2S7jx8,AIzaSyAWHI0fiVStupmAB2O1gtojTVDCooKPLKE,AIzaSyDw_GBYnhqzOcM49N0Fm78A0OSfUqDgPIA,AIzaSyB6qRgKJmjsC7mFJYOMf1V7UzFHRJTzC24,AIzaSyD6CoaZHBAYzrGbuFQT5B7QrGQdEqv2pL8,AIzaSyBWT2Rxu6-NrzVoiFN4CccjlBygXFWg-y8,AIzaSyCYNMZ7OngDEsr0hmburOjBRvLeUMf9NZo,AIzaSyCYNMZ7OngDEsr0hmburOjBRvLeUMf9NZo
